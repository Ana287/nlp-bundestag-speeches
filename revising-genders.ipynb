# %%
import pandas as pd
from xml.etree import ElementTree as ET
import re
import pickle

# %%
# load data
df = pd.read_pickle('C:/Users/Ana/OneDrive - Hochschule Düsseldorf/MA/data_merged.pkl')

df.head()
# Out:
#                                                 text       date  \
# 0    Sehr geehrter Herr Alterspräsident! So muss ... 2021-10-26
# 1    Herr Präsident! Liebe Kolleginnen und Kolleg... 2021-10-26
# 2    Sehr geehrter Herr Alterspräsident Wolfgang ... 2021-10-26
# 3    Sehr geehrter Herr Präsident! Meine lieben K... 2021-10-26
# 4    Herr Alterspräsident! Lassen Sie mich zunäch... 2021-10-26
#
#   legislative_period        speaker_name speaker_gender speaker_role  \
# 0                 20  Gabriele Katzmarek         female         None
# 1                 20       Stefan Müller           male         None
# 2                 20    Britta Haßelmann         female         None
# 3                 20     Marco Buschmann           male         None
# 4                 20    Stephan Brandner           male         None
#
#            speaker_party                                           comments  \
# 0                    SPD  [(Beifall bei der SPD sowie bei Abgeordneten d...
# 1                CDU/CSU  [(Beifall bei der CDU/CSU sowie bei Abgeordnet...
# 2  BÜNDNIS 90/DIE GRÜNEN  [(Beifall beim BÜNDNIS 90/DIE GRÜNEN und bei d...
# 3                    FDP  [(Jan Korte [DIE LINKE]: Oder Jugendweihe!), (...
# 4                    AfD  [(Beifall bei der AfD), (Beifall bei Abgeordne...
#
#           id  speaker_id  speech_length
# 0  SP-2021-0        1299           2593
# 1  SP-2021-1        4028           3796
# 2  SP-2021-2         451           4301
# 3  SP-2021-3        3083           4555
# 4  SP-2021-4        4055           5996

# %%
# gender counts
df.groupby('speaker_gender')['speaker_id'].nunique()
# Out:
# speaker_gender
# female    1057
# male      3656
# Name: speaker_id, dtype: int64

# %%
# parse XML file and save member data to pickle file for later use
filepath = 'C:/Users/Ana/OneDrive - Hochschule Düsseldorf/MA/data/MdB-Stammdaten/MDB_STAMMDATEN.XML'
member_data = []

data = ET.parse(filepath)
root = data.getroot()

# iterate over the <MDB> elements and extract their data
for member in root.iter('MDB'):

    # get speaker name(s)
    last_names = []
    full_names = []
    titles = []

    for name in member.iterfind('.//NAME'):
        last_name = name.find('NACHNAME').text
        first_name = name.find('VORNAME').text
        full_name = first_name + ' ' + last_name

        last_names.append(last_name)
        full_names.append(full_name)

        title = name.find('ANREDE_TITEL').text
        ac_title = name.find('AKAD_TITEL').text

        titles.append(title) if title is not None else None
        titles.append(ac_title) if title is not None else None

        
    # get gender and party
    gender = member.find('.//GESCHLECHT').text
    party = member.find('.//PARTEI_KURZ').text

    # get election periods
    periods = []
    for period in member.iterfind('.//WAHLPERIODE'):
        periods.append(int(period.find('WP').text))   
    
    # append all data to member_data
    member_data.append({
        'full_name': full_names,
        'first_name': first_name,
        'last_name': last_names,
        'gender': 'male' if gender == 'männlich' else 'female',
        'party': party if party is not None else None,
        'periods': periods if periods is not None else None,
        'titles': titles
    })
    
with open('data/member_data.pkl', 'wb') as f:
    pickle.dump(member_data, f)

member_data
# Out:
# [{'full_name': ['Manfred Abelein'],
#   'first_name': 'Manfred',
#   'last_name': ['Abelein'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [5, 6, 7, 8, 9, 10, 11],
#   'titles': ['Dr.', 'Prof. Dr.']},
#  {'full_name': ['Ernst Achenbach'],
#   'first_name': 'Ernst',
#   'last_name': ['Achenbach'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [3, 4, 5, 6, 7],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Annemarie Ackermann'],
#   'first_name': 'Annemarie',
#   'last_name': ['Ackermann'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [2, 3, 4],
#   'titles': []},
#  {'full_name': ['Else Ackermann'],
#   'first_name': 'Else',
#   'last_name': ['Ackermann'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [11, 12],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Ulrich Adam'],
#   'first_name': 'Ulrich',
#   'last_name': ['Adam'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [12, 13, 14, 15, 16],
#   'titles': []},
#  {'full_name': ['Rudolf Adams'],
#   'first_name': 'Rudolf',
#   'last_name': ['Adams'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5, 6, 7, 8],
#   'titles': []},
#  {'full_name': ['Raban Adelmann'],
#   'first_name': 'Raban',
#   'last_name': ['Adelmann'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3],
#   'titles': []},
#  {'full_name': ['Konrad Adenauer'],
#   'first_name': 'Konrad',
#   'last_name': ['Adenauer'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3, 4, 5],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Brigitte Adler'],
#   'first_name': 'Brigitte',
#   'last_name': ['Adler'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [11, 12, 13, 14],
#   'titles': []},
#  {'full_name': ['Eduard Adorno'],
#   'first_name': 'Eduard',
#   'last_name': ['Adorno'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [4, 5, 6],
#   'titles': []},
#  {'full_name': ['Jochen Aerssen'],
#   'first_name': 'Jochen',
#   'last_name': ['Aerssen'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [8, 9],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Willi Agatz'],
#   'first_name': 'Willi',
#   'last_name': ['Agatz'],
#   'gender': 'male',
#   'party': 'KPD',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Conrad Ahlers'],
#   'first_name': 'Conrad',
#   'last_name': ['Ahlers'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [7, 8],
#   'titles': []},
#  {'full_name': ['Adolf Ahrens'],
#   'first_name': 'Adolf',
#   'last_name': ['Ahrens'],
#   'gender': 'male',
#   'party': 'DP',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Hermann Ahrens'],
#   'first_name': 'Hermann',
#   'last_name': ['Ahrens'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5],
#   'titles': []},
#  {'full_name': ['Karl Ahrens'],
#   'first_name': 'Karl',
#   'last_name': ['Ahrens'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [6, 7, 8, 9, 10, 11],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Heinrich Aigner'],
#   'first_name': 'Heinrich',
#   'last_name': ['Aigner'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [3, 4, 5, 6, 7, 8],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Siegbert Alber', 'Siegbert Alber'],
#   'first_name': 'Siegbert',
#   'last_name': ['Alber', 'Alber'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6, 7, 8],
#   'titles': []},
#  {'full_name': ['Johannes Albers'],
#   'first_name': 'Johannes',
#   'last_name': ['Albers'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2],
#   'titles': []},
#  {'full_name': ['Luise Albertz'],
#   'first_name': 'Luise',
#   'last_name': ['Albertz'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Ina Albowitz', 'Ina Albowitz-Freytag'],
#   'first_name': 'Ina',
#   'last_name': ['Albowitz', 'Albowitz-Freytag'],
#   'gender': 'female',
#   'party': 'FDP',
#   'periods': [12, 13, 14],
#   'titles': []},
#  {'full_name': ['Ernst Albrecht'],
#   'first_name': 'Ernst',
#   'last_name': ['Albrecht'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2],
#   'titles': []},
#  {'full_name': ['Lisa Albrecht'],
#   'first_name': 'Lisa',
#   'last_name': ['Albrecht'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [1, 2, 3],
#   'titles': []},
#  {'full_name': ['Michael Albrecht'],
#   'first_name': 'Michael',
#   'last_name': ['Albrecht'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Peter Alltschekow'],
#   'first_name': 'Peter',
#   'last_name': ['Alltschekow'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [12],
#   'titles': []},
#  {'full_name': ['Odal Alten-Nordheim'],
#   'first_name': 'Odal',
#   'last_name': ['Alten-Nordheim'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6, 7],
#   'titles': []},
#  {'full_name': ['Walter Althammer'],
#   'first_name': 'Walter',
#   'last_name': ['Althammer'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [4, 5, 6, 7, 8, 9, 10],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Walter Altherr'],
#   'first_name': 'Walter',
#   'last_name': ['Altherr'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [12],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Jakob Altmaier'],
#   'first_name': 'Jakob',
#   'last_name': ['Altmaier'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4],
#   'titles': []},
#  {'full_name': ['Wilhelm Altvater'],
#   'first_name': 'Wilhelm',
#   'last_name': ['Altvater'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3],
#   'titles': []},
#  {'full_name': ['Rudolf Amelunxen'],
#   'first_name': 'Rudolf',
#   'last_name': ['Amelunxen'],
#   'gender': 'male',
#   'party': 'DZP',
#   'periods': [1],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Andreas Amende'],
#   'first_name': 'Andreas',
#   'last_name': ['Amende'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Max Amling'],
#   'first_name': 'Max',
#   'last_name': ['Amling'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [7, 8, 9, 10, 11],
#   'titles': []},
#  {'full_name': ['Franz Amrehn'],
#   'first_name': 'Franz',
#   'last_name': ['Amrehn'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6, 7, 8, 9],
#   'titles': []},
#  {'full_name': ['Jürgen Anbuhl'],
#   'first_name': 'Jürgen',
#   'last_name': ['Anbuhl'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [6, 7],
#   'titles': []},
#  {'full_name': ['Artur Anders'],
#   'first_name': 'Artur',
#   'last_name': ['Anders'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4],
#   'titles': []},
#  {'full_name': ['Gerd Andres'],
#   'first_name': 'Gerd',
#   'last_name': ['Andres'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [11, 12, 13, 14, 15, 16],
#   'titles': ['Dr. h. c.', 'Dr. h. c.']},
#  {'full_name': ['Joachim Angermeyer'],
#   'first_name': 'Joachim',
#   'last_name': ['Angermeyer'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [8],
#   'titles': []},
#  {'full_name': ['Dieter Annies'],
#   'first_name': 'Dieter',
#   'last_name': ['Annies'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Maria Ansorge'],
#   'first_name': 'Maria',
#   'last_name': ['Ansorge'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Robert Antretter'],
#   'first_name': 'Robert',
#   'last_name': ['Antretter'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [9, 10, 11, 12, 13],
#   'titles': []},
#  {'full_name': ['Hans Apel'],
#   'first_name': 'Hans',
#   'last_name': ['Apel'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5, 6, 7, 8, 9, 10, 11],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Walter Arendt', 'Walter Arendt'],
#   'first_name': 'Walter',
#   'last_name': ['Arendt', 'Arendt'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4, 5, 6, 7, 8],
#   'titles': []},
#  {'full_name': ['Anton Aretin'],
#   'first_name': 'Anton',
#   'last_name': ['Aretin'],
#   'gender': 'male',
#   'party': 'FU',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Josef Arndgen'],
#   'first_name': 'Josef',
#   'last_name': ['Arndgen'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3, 4],
#   'titles': []},
#  {'full_name': ['Adolf Arndt', 'Adolf Arndt', 'Adolf Arndt'],
#   'first_name': 'Adolf',
#   'last_name': ['Arndt', 'Arndt', 'Arndt'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4, 5],
#   'titles': ['Dr.', 'Dr.', 'Dr.', 'Dr.', 'Dr.', 'Dr.']},
#  {'full_name': ['Claus Arndt'],
#   'first_name': 'Claus',
#   'last_name': ['Arndt'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5, 6, 7],
#   'titles': ['Dr.', 'Prof. Dr.']},
#  {'full_name': ['Klaus Dieter Arndt'],
#   'first_name': 'Klaus Dieter',
#   'last_name': ['Arndt'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5, 6, 7],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Otto Arnholz'],
#   'first_name': 'Otto',
#   'last_name': ['Arnholz'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2],
#   'titles': []},
#  {'full_name': ['Gottfried Arnold'],
#   'first_name': 'Gottfried',
#   'last_name': ['Arnold'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [4, 5, 6, 7, 8, 9],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Karl Arnold'],
#   'first_name': 'Karl',
#   'last_name': ['Arnold'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3],
#   'titles': ['Dr.', 'Dr. - Ing. e. h.']},
#  {'full_name': ['Thea Arnold'],
#   'first_name': 'Thea',
#   'last_name': ['Arnold'],
#   'gender': 'female',
#   'party': 'FU',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Helmut Artzinger'],
#   'first_name': 'Helmut',
#   'last_name': ['Artzinger'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [4, 5, 6, 7],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Albrecht Aschoff'],
#   'first_name': 'Albrecht',
#   'last_name': ['Aschoff'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [4],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Heinz Assmann'],
#   'first_name': 'Heinz',
#   'last_name': ['Assmann'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [9],
#   'titles': []},
#  {'full_name': ['Karl Atzenroth'],
#   'first_name': 'Karl',
#   'last_name': ['Atzenroth'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [1, 2, 3, 4],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Dieter Auch'],
#   'first_name': 'Dieter',
#   'last_name': ['Auch'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [9],
#   'titles': []},
#  {'full_name': ['Heinrich Auge'],
#   'first_name': 'Heinrich',
#   'last_name': ['Auge'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3, 4, 5],
#   'titles': []},
#  {'full_name': ['Hans-Jürgen Augstein'],
#   'first_name': 'Hans-Jürgen',
#   'last_name': ['Augstein'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [7, 8],
#   'titles': []},
#  {'full_name': ['Rudolf Augstein'],
#   'first_name': 'Rudolf',
#   'last_name': ['Augstein'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [7],
#   'titles': []},
#  {'full_name': ['Anneliese Augustin'],
#   'first_name': 'Anneliese',
#   'last_name': ['Augustin'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [10, 11, 12, 13],
#   'titles': []},
#  {'full_name': ['Jürgen Augustinowitz'],
#   'first_name': 'Jürgen',
#   'last_name': ['Augustinowitz'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [12, 13],
#   'titles': []},
#  {'full_name': ['Hendrik Auhagen'],
#   'first_name': 'Hendrik',
#   'last_name': ['Auhagen'],
#   'gender': 'male',
#   'party': 'GRÜNE',
#   'periods': [10],
#   'titles': []},
#  {'full_name': ['Hermann Aumer'],
#   'first_name': 'Hermann',
#   'last_name': ['Aumer'],
#   'gender': 'male',
#   'party': 'BP',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Dietrich Austermann'],
#   'first_name': 'Dietrich',
#   'last_name': ['Austermann'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [9, 10, 11, 12, 13, 14, 15],
#   'titles': []},
#  {'full_name': ['Herbert Baack'],
#   'first_name': 'Herbert',
#   'last_name': ['Baack'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [6, 7, 8, 9],
#   'titles': []},
#  {'full_name': ['Fritz Baade'],
#   'first_name': 'Fritz',
#   'last_name': ['Baade'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4],
#   'titles': ['Dr.', 'Dr. Dr. h. c.']},
#  {'full_name': ['Gisela Babel'],
#   'first_name': 'Gisela',
#   'last_name': ['Babel'],
#   'gender': 'female',
#   'party': 'FDP',
#   'periods': [12, 13],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Franz Josef Bach'],
#   'first_name': 'Franz Josef',
#   'last_name': ['Bach'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6],
#   'titles': ['Dr.', 'Dr. - Ing.']},
#  {'full_name': ['Robert Bach'],
#   'first_name': 'Robert',
#   'last_name': ['Bach'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3],
#   'titles': []},
#  {'full_name': ['Hermann Bachmaier'],
#   'first_name': 'Hermann',
#   'last_name': ['Bachmaier'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [10, 11, 12, 13, 14, 15],
#   'titles': []},
#  {'full_name': ['Harri Bading'],
#   'first_name': 'Harri',
#   'last_name': ['Bading'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3, 4, 5],
#   'titles': []},
#  {'full_name': ['Siegfried Bärsch'],
#   'first_name': 'Siegfried',
#   'last_name': ['Bärsch'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Hans-Joachim Baeuchle'],
#   'first_name': 'Hans-Joachim',
#   'last_name': ['Baeuchle'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [6],
#   'titles': []},
#  {'full_name': ['Willi Bäuerle'],
#   'first_name': 'Willi',
#   'last_name': ['Bäuerle'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4, 5, 6, 7],
#   'titles': []},
#  {'full_name': ['Rudolf Bäumer'],
#   'first_name': 'Rudolf',
#   'last_name': ['Bäumer'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3, 4],
#   'titles': []},
#  {'full_name': ['Wilhelm Bahlburg'],
#   'first_name': 'Wilhelm',
#   'last_name': ['Bahlburg'],
#   'gender': 'male',
#   'party': 'DP',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Dietrich Bahner'],
#   'first_name': 'Dietrich',
#   'last_name': ['Bahner'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [8, 9],
#   'titles': []},
#  {'full_name': ['Egon Bahr'],
#   'first_name': 'Egon',
#   'last_name': ['Bahr'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [7, 8, 9, 10, 11],
#   'titles': []},
#  {'full_name': ['Fritz Baier', 'Fritz Baier', 'Fritz Baier'],
#   'first_name': 'Fritz',
#   'last_name': ['Baier', 'Baier', 'Baier'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2, 3, 4, 5, 6, 7],
#   'titles': []},
#  {'full_name': ['Albert Baldauf'],
#   'first_name': 'Albert',
#   'last_name': ['Baldauf'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3, 4],
#   'titles': []},
#  {'full_name': ['Siegfried Balke'],
#   'first_name': 'Siegfried',
#   'last_name': ['Balke'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [3, 4, 5],
#   'titles': ['Dr.', 'Dr. - Ing. Dr. h. c.']},
#  {'full_name': ['Bernhard Balkenhol'],
#   'first_name': 'Bernhard',
#   'last_name': ['Balkenhol'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3, 4, 5, 6],
#   'titles': []},
#  {'full_name': ['Hans Bals'],
#   'first_name': 'Hans',
#   'last_name': ['Bals'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [2, 3, 4, 5, 6],
#   'titles': []},
#  {'full_name': ['Frolinde Balser'],
#   'first_name': 'Frolinde',
#   'last_name': ['Balser'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [8],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Andreas Baltes'],
#   'first_name': 'Andreas',
#   'last_name': ['Baltes'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5],
#   'titles': []},
#  {'full_name': ['Georg Bamberg'],
#   'first_name': 'Georg',
#   'last_name': ['Bamberg'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [9, 10, 11],
#   'titles': []},
#  {'full_name': ['Martin Bangemann'],
#   'first_name': 'Martin',
#   'last_name': ['Bangemann'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [7, 8, 11],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Wilhelm Banse'],
#   'first_name': 'Wilhelm',
#   'last_name': ['Banse'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [2],
#   'titles': []},
#  {'full_name': ['Angelika Barbe'],
#   'first_name': 'Angelika',
#   'last_name': ['Barbe'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [11, 12],
#   'titles': []},
#  {'full_name': ['Hermann Barche'],
#   'first_name': 'Hermann',
#   'last_name': ['Barche'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5, 6, 7],
#   'titles': []},
#  {'full_name': ['Sabine Bard', 'Sabine Bard-Kröniger'],
#   'first_name': 'Sabine',
#   'last_name': ['Bard', 'Bard-Kröniger'],
#   'gender': 'female',
#   'party': 'GRÜNE',
#   'periods': [10],
#   'titles': ['Dr.', 'Dr.', 'Dr.', 'Dr.']},
#  {'full_name': ['Hans Bardens'],
#   'first_name': 'Hans',
#   'last_name': ['Bardens'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5, 6, 7, 8, 9],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Heinz-Günter Bargfrede'],
#   'first_name': 'Heinz-Günter',
#   'last_name': ['Bargfrede'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [12, 13],
#   'titles': []},
#  {'full_name': ['Heinrich Barlage'],
#   'first_name': 'Heinrich',
#   'last_name': ['Barlage'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2],
#   'titles': []},
#  {'full_name': ['Wolfgang Bartels'],
#   'first_name': 'Wolfgang',
#   'last_name': ['Bartels'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Lothar Barthel'],
#   'first_name': 'Lothar',
#   'last_name': ['Barthel'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Walter Bartram'],
#   'first_name': 'Walter',
#   'last_name': ['Bartram'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Holger Bartsch'],
#   'first_name': 'Holger',
#   'last_name': ['Bartsch'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [12],
#   'titles': []},
#  {'full_name': ['Willy Bartsch'],
#   'first_name': 'Willy',
#   'last_name': ['Bartsch'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4, 5, 6],
#   'titles': []},
#  {'full_name': ['Rainer Barzel'],
#   'first_name': 'Rainer',
#   'last_name': ['Barzel'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3, 4, 5, 6, 7, 8, 9, 10],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Gert Bastian'],
#   'first_name': 'Gert',
#   'last_name': ['Bastian'],
#   'gender': 'male',
#   'party': 'GRÜNE',
#   'periods': [10],
#   'titles': []},
#  {'full_name': ['Hans Batz'],
#   'first_name': 'Hans',
#   'last_name': ['Batz'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [6, 7, 8],
#   'titles': []},
#  {'full_name': ['Hannsheinz Bauer'],
#   'first_name': 'Hannsheinz',
#   'last_name': ['Bauer'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [2, 3, 4, 5, 6],
#   'titles': []},
#  {'full_name': ['Harald Bauer'],
#   'first_name': 'Harald',
#   'last_name': ['Bauer'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Josef Bauer'],
#   'first_name': 'Josef',
#   'last_name': ['Bauer'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Wolf Bauer'],
#   'first_name': 'Wolf',
#   'last_name': ['Bauer'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [11, 12, 13, 14, 15, 16],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Friedrich Bauereisen'],
#   'first_name': 'Friedrich',
#   'last_name': ['Bauereisen'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [1, 2, 3],
#   'titles': []},
#  {'full_name': ['Bernhard Bauknecht'],
#   'first_name': 'Bernhard',
#   'last_name': ['Bauknecht'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Gerhart Rudolf Baum'],
#   'first_name': 'Gerhart Rudolf',
#   'last_name': ['Baum'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [7, 8, 9, 10, 11, 12],
#   'titles': []},
#  {'full_name': ['Brigitte Baumeister'],
#   'first_name': 'Brigitte',
#   'last_name': ['Baumeister'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [12, 13, 14],
#   'titles': []},
#  {'full_name': ['Josef Baumgartner'],
#   'first_name': 'Josef',
#   'last_name': ['Baumgartner'],
#   'gender': 'male',
#   'party': 'BP',
#   'periods': [1],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Georg Baur'],
#   'first_name': 'Georg',
#   'last_name': ['Baur'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Valentin Baur'],
#   'first_name': 'Valentin',
#   'last_name': ['Baur'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3],
#   'titles': []},
#  {'full_name': ['Paul Bausch'],
#   'first_name': 'Paul',
#   'last_name': ['Bausch'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3, 4],
#   'titles': []},
#  {'full_name': ['Hans Bay'],
#   'first_name': 'Hans',
#   'last_name': ['Bay'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3, 6],
#   'titles': []},
#  {'full_name': ['Alfons Bayerl'],
#   'first_name': 'Alfons',
#   'last_name': ['Bayerl'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5, 6, 7, 8],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Konstantin Bayern'],
#   'first_name': 'Konstantin',
#   'last_name': ['Bayern'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [5],
#   'titles': []},
#  {'full_name': ['Richard Bayha'],
#   'first_name': 'Richard',
#   'last_name': ['Bayha'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [8, 9, 10, 11, 12],
#   'titles': []},
#  {'full_name': ['Helmut Bazille'],
#   'first_name': 'Helmut',
#   'last_name': ['Bazille'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Walter Becher'],
#   'first_name': 'Walter',
#   'last_name': ['Becher'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [5, 6, 7, 8],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Karl Bechert', 'Karl Bechert'],
#   'first_name': 'Karl',
#   'last_name': ['Bechert', 'Bechert'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3, 4, 5, 6],
#   'titles': ['Dr.', 'Dr. Dr. h. c.', 'Dr.', 'Dr. Dr. h. c.']},
#  {'full_name': ['Curt Becker'],
#   'first_name': 'Curt',
#   'last_name': ['Becker'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3, 4, 6, 7],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Fritz Becker'],
#   'first_name': 'Fritz',
#   'last_name': ['Becker'],
#   'gender': 'male',
#   'party': 'DP',
#   'periods': [2],
#   'titles': []},
#  {'full_name': ['Helmuth Becker'],
#   'first_name': 'Helmuth',
#   'last_name': ['Becker'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [6, 7, 8, 9, 10, 11, 12],
#   'titles': []},
#  {'full_name': ['Josef Becker', 'Josef Becker'],
#   'first_name': 'Josef',
#   'last_name': ['Becker', 'Becker'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3, 4, 5, 6],
#   'titles': []},
#  {'full_name': ['Karl Becker'],
#   'first_name': 'Karl',
#   'last_name': ['Becker'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [8, 9, 10, 11],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Max Becker'],
#   'first_name': 'Max',
#   'last_name': ['Becker'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [1, 2, 3],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Roland Becker'],
#   'first_name': 'Roland',
#   'last_name': ['Becker'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Ingrid Becker-Inglau'],
#   'first_name': 'Ingrid',
#   'last_name': ['Becker-Inglau'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [11, 12, 13, 14],
#   'titles': []},
#  {'full_name': ['Klaus Beckmann'],
#   'first_name': 'Klaus',
#   'last_name': ['Beckmann'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [9, 10, 11, 12],
#   'titles': []},
#  {'full_name': ['Angelika Beer'],
#   'first_name': 'Angelika',
#   'last_name': ['Beer'],
#   'gender': 'female',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'periods': [11, 13, 14],
#   'titles': []},
#  {'full_name': ['Friedrich Beermann'],
#   'first_name': 'Friedrich',
#   'last_name': ['Beermann'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [6, 7],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Walter Behrendt'],
#   'first_name': 'Walter',
#   'last_name': ['Behrendt'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3, 4, 5, 6, 7],
#   'titles': []},
#  {'full_name': ['Arno Behrisch'],
#   'first_name': 'Arno',
#   'last_name': ['Behrisch'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3],
#   'titles': []},
#  {'full_name': ['Meinrad Belle'],
#   'first_name': 'Meinrad',
#   'last_name': ['Belle'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [12, 13, 14],
#   'titles': []},
#  {'full_name': ['Ernst Benda'],
#   'first_name': 'Ernst',
#   'last_name': ['Benda'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3, 4, 5, 6],
#   'titles': ['Dr.', 'Prof. Dr.']},
#  {'full_name': ['Reinhold F. Bender'],
#   'first_name': 'Reinhold F.',
#   'last_name': ['Bender'],
#   'gender': 'male',
#   'party': 'GB/ BHE',
#   'periods': [2],
#   'titles': []},
#  {'full_name': ['Ursula Benedix', 'Ursula Benedix-Engler'],
#   'first_name': 'Ursula',
#   'last_name': ['Benedix', 'Benedix-Engler'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [7, 8, 9],
#   'titles': []},
#  {'full_name': ['Franziska Bennemann'],
#   'first_name': 'Franziska',
#   'last_name': ['Bennemann'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [2, 3],
#   'titles': []},
#  {'full_name': ['Gerold Benz'],
#   'first_name': 'Gerold',
#   'last_name': ['Benz'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [7, 8],
#   'titles': []},
#  {'full_name': ['August Berberich'],
#   'first_name': 'August',
#   'last_name': ['Berberich'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3, 4, 5, 6],
#   'titles': []},
#  {'full_name': ['Franz Berding'],
#   'first_name': 'Franz',
#   'last_name': ['Berding'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6],
#   'titles': []},
#  {'full_name': ['Fritz Berendsen'],
#   'first_name': 'Fritz',
#   'last_name': ['Berendsen'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2, 3, 5],
#   'titles': []},
#  {'full_name': ['Hermann Berg'],
#   'first_name': 'Hermann',
#   'last_name': ['Berg'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [2],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Hans Berger'],
#   'first_name': 'Hans',
#   'last_name': ['Berger'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [12, 13],
#   'titles': []},
#  {'full_name': ['Lieselotte Berger', 'Lieselotte Berger'],
#   'first_name': 'Lieselotte',
#   'last_name': ['Berger', 'Berger'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [6, 7, 8, 9, 10, 11],
#   'titles': []},
#  {'full_name': ['Markus Berger', 'Markus Berger'],
#   'first_name': 'Markus',
#   'last_name': ['Berger', 'Berger'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [8, 9, 10],
#   'titles': []},
#  {'full_name': ['Ulrich Berger'],
#   'first_name': 'Ulrich',
#   'last_name': ['Berger'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3, 4, 5, 6, 7, 8],
#   'titles': []},
#  {'full_name': ['Margarete Heise', 'Margarete Berger-Heise'],
#   'first_name': 'Margarete',
#   'last_name': ['Heise', 'Berger-Heise'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Wolfram Bergerowski'],
#   'first_name': 'Wolfram',
#   'last_name': ['Bergerowski'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [9],
#   'titles': []},
#  {'full_name': ['Karl Bergmann'],
#   'first_name': 'Karl',
#   'last_name': ['Bergmann'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4, 5, 6],
#   'titles': []},
#  {'full_name': ['Sabine Bergmann-Pohl'],
#   'first_name': 'Sabine',
#   'last_name': ['Bergmann-Pohl'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [11, 12, 13, 14],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Bernhard Gerhard Bergmeyer'],
#   'first_name': 'Bernhard Gerhard',
#   'last_name': ['Bergmeyer'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2, 3],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Ludwig Bergstraesser'],
#   'first_name': 'Ludwig',
#   'last_name': ['Bergstraesser'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Karl Wilhelm Berkhan'],
#   'first_name': 'Karl Wilhelm',
#   'last_name': ['Berkhan'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3, 4, 5, 6, 7],
#   'titles': []},
#  {'full_name': ['August Berlin'],
#   'first_name': 'August',
#   'last_name': ['Berlin'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4, 5, 6],
#   'titles': []},
#  {'full_name': ['Franz-Josef Berners'],
#   'first_name': 'Franz-Josef',
#   'last_name': ['Berners'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [10],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Hans Gottfried Bernrath'],
#   'first_name': 'Hans Gottfried',
#   'last_name': ['Bernrath'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [9, 10, 11, 12, 13],
#   'titles': []},
#  {'full_name': ['Walter Bersch'],
#   'first_name': 'Walter',
#   'last_name': ['Bersch'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [12],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Erich Berschkeit'],
#   'first_name': 'Erich',
#   'last_name': ['Berschkeit'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [9, 10],
#   'titles': []},
#  {'full_name': ['Helmut Bertram'],
#   'first_name': 'Helmut',
#   'last_name': ['Bertram'],
#   'gender': 'male',
#   'party': 'FU',
#   'periods': [1],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Johann Christoph Besch'],
#   'first_name': 'Johann Christoph',
#   'last_name': ['Besch'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [8],
#   'titles': []},
#  {'full_name': ['Anton Besold'],
#   'first_name': 'Anton',
#   'last_name': ['Besold'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [1, 3, 4, 5],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Emil Bettgenhäuser'],
#   'first_name': 'Emil',
#   'last_name': ['Bettgenhäuser'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3],
#   'titles': []},
#  {'full_name': ['Friedhelm Julius Beucher'],
#   'first_name': 'Friedhelm Julius',
#   'last_name': ['Beucher'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [12, 13, 14],
#   'titles': []},
#  {'full_name': ['Willi Beuster'],
#   'first_name': 'Willi',
#   'last_name': ['Beuster'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4, 5],
#   'titles': []},
#  {'full_name': ['Karl Bewerunge'],
#   'first_name': 'Karl',
#   'last_name': ['Bewerunge'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [4, 5, 6, 7],
#   'titles': []},
#  {'full_name': ['Lucie Beyer', 'Lucie Kurlbaum-Beyer'],
#   'first_name': 'Lucie',
#   'last_name': ['Beyer', 'Kurlbaum-Beyer'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Hermann Biechele'],
#   'first_name': 'Hermann',
#   'last_name': ['Biechele'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [4, 5, 6, 7, 8],
#   'titles': []},
#  {'full_name': ['Kurt H. Biedenkopf'],
#   'first_name': 'Kurt H.',
#   'last_name': ['Biedenkopf'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [8, 11],
#   'titles': ['Dr.', 'Prof. Dr.']},
#  {'full_name': ['Anna Maria Bieganowski'],
#   'first_name': 'Anna Maria',
#   'last_name': ['Bieganowski'],
#   'gender': 'female',
#   'party': 'DP',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Curt Biegler'],
#   'first_name': 'Curt',
#   'last_name': ['Biegler'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4],
#   'titles': []},
#  {'full_name': ['Alfred Biehle'],
#   'first_name': 'Alfred',
#   'last_name': ['Biehle'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [6, 7, 8, 9, 10, 11],
#   'titles': []},
#  {'full_name': ['Karl Bielig'],
#   'first_name': 'Karl',
#   'last_name': ['Bielig'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Adolf Bieringer'],
#   'first_name': 'Adolf',
#   'last_name': ['Bieringer'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [4],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Hans-Dirk Bierling'],
#   'first_name': 'Hans-Dirk',
#   'last_name': ['Bierling'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [12, 13, 14],
#   'titles': []},
#  {'full_name': ['Günter Biermann'],
#   'first_name': 'Günter',
#   'last_name': ['Biermann'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4, 5, 6, 7, 8, 9],
#   'titles': []},
#  {'full_name': ['Rudolf Bindig'],
#   'first_name': 'Rudolf',
#   'last_name': ['Bindig'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [8, 9, 10, 11, 12, 13, 14, 15],
#   'titles': []},
#  {'full_name': ['Willi Birkelbach'],
#   'first_name': 'Willi',
#   'last_name': ['Birkelbach'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4],
#   'titles': []},
#  {'full_name': ['Kurt Birrenbach'],
#   'first_name': 'Kurt',
#   'last_name': ['Birrenbach'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3, 4, 5, 6, 7],
#   'titles': ['Dr.', 'Dr. Dr. h. c.']},
#  {'full_name': ['Marianne Birthler'],
#   'first_name': 'Marianne',
#   'last_name': ['Birthler'],
#   'gender': 'female',
#   'party': 'DIE GRÜNEN/BÜNDNIS 90',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Otto Bismarck'],
#   'first_name': 'Otto',
#   'last_name': ['Bismarck'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2, 3, 4],
#   'titles': []},
#  {'full_name': ['Philipp Bismarck'],
#   'first_name': 'Philipp',
#   'last_name': ['Bismarck'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6, 7, 8],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Otto Bittelmann'],
#   'first_name': 'Otto',
#   'last_name': ['Bittelmann'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6],
#   'titles': []},
#  {'full_name': ['Ingrid Bittner'],
#   'first_name': 'Ingrid',
#   'last_name': ['Bittner'],
#   'gender': 'female',
#   'party': 'PDS',
#   'periods': [11],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Petra Bläss-Rafajlovski'],
#   'first_name': 'Petra',
#   'last_name': ['Bläss-Rafajlovski'],
#   'gender': 'female',
#   'party': 'PDS',
#   'periods': [12, 13, 14],
#   'titles': []},
#  {'full_name': ['Peter Blachstein'],
#   'first_name': 'Peter',
#   'last_name': ['Blachstein'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Bertram Blank'],
#   'first_name': 'Bertram',
#   'last_name': ['Blank'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [7, 8],
#   'titles': []},
#  {'full_name': ['Joseph-Theodor Blank'],
#   'first_name': 'Joseph-Theodor',
#   'last_name': ['Blank'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [10, 11, 12, 13, 14],
#   'titles': ['Dr.', 'Prof. Dr.']},
#  {'full_name': ['Martin Blank'],
#   'first_name': 'Martin',
#   'last_name': ['Blank'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [1, 2],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Renate Blank'],
#   'first_name': 'Renate',
#   'last_name': ['Blank'],
#   'gender': 'female',
#   'party': 'CSU',
#   'periods': [12, 13, 14, 15, 16],
#   'titles': []},
#  {'full_name': ['Theodor Blank', 'Theodor Blank'],
#   'first_name': 'Theodor',
#   'last_name': ['Blank', 'Blank'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3, 4, 5, 6],
#   'titles': []},
#  {'full_name': ['Paul Bleiß'],
#   'first_name': 'Paul',
#   'last_name': ['Bleiß'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Heribert Blens'],
#   'first_name': 'Heribert',
#   'last_name': ['Blens'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [10, 11, 12, 13, 14],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Peter Bleser'],
#   'first_name': 'Peter',
#   'last_name': ['Bleser'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [12, 13, 14, 15, 16, 17, 18, 19],
#   'titles': []},
#  {'full_name': ['Hildegard Bleyler', 'Hildegard Bleyler'],
#   'first_name': 'Hildegard',
#   'last_name': ['Bleyler', 'Bleyler'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [2, 3, 4],
#   'titles': ['Dr.', 'Dr.', 'Dr.', 'Dr.']},
#  {'full_name': ['Hans Blöcker'],
#   'first_name': 'Hans',
#   'last_name': ['Blöcker'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Irma Blohm'],
#   'first_name': 'Irma',
#   'last_name': ['Blohm'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [4, 5, 3],
#   'titles': []},
#  {'full_name': ['Franz Blücher'],
#   'first_name': 'Franz',
#   'last_name': ['Blücher'],
#   'gender': 'male',
#   'party': 'DP',
#   'periods': [1, 2, 3],
#   'titles': ['Dr.', 'Dr. h. c.']},
#  {'full_name': ['Rudolf Blügel'],
#   'first_name': 'Rudolf',
#   'last_name': ['Blügel'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [8],
#   'titles': []},
#  {'full_name': ['Norbert Blüm'],
#   'first_name': 'Norbert',
#   'last_name': ['Blüm'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [7, 8, 9, 10, 11, 12, 13, 14],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Friedrich Blume'],
#   'first_name': 'Friedrich',
#   'last_name': ['Blume'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5],
#   'titles': []},
#  {'full_name': ['Erik Bernhard Blumenfeld'],
#   'first_name': 'Erik Bernhard',
#   'last_name': ['Blumenfeld'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [4, 5, 6, 7, 8],
#   'titles': []},
#  {'full_name': ['Lieselott Blunck', 'Lieselott Blunck'],
#   'first_name': 'Lieselott',
#   'last_name': ['Blunck', 'Blunck'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [9, 10, 11, 12, 13],
#   'titles': []},
#  {'full_name': ['Michaela Blunk'],
#   'first_name': 'Michaela',
#   'last_name': ['Blunk'],
#   'gender': 'female',
#   'party': 'FDP',
#   'periods': [12],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Paul Bock'],
#   'first_name': 'Paul',
#   'last_name': ['Bock'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2],
#   'titles': []},
#  {'full_name': ['Thea Bock'],
#   'first_name': 'Thea',
#   'last_name': ['Bock'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [12],
#   'titles': []},
#  {'full_name': ['Helmut Bockelberg'],
#   'first_name': 'Helmut',
#   'last_name': ['Bockelberg'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6, 7],
#   'titles': []},
#  {'full_name': ['Ernst Bodelschwingh'],
#   'first_name': 'Ernst',
#   'last_name': ['Bodelschwingh'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2, 3, 4],
#   'titles': []},
#  {'full_name': ['Hans Bodensteiner'],
#   'first_name': 'Hans',
#   'last_name': ['Bodensteiner'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Rolf Böger'],
#   'first_name': 'Rolf',
#   'last_name': ['Böger'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [7],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Franz Böhm', 'Franz Böhm'],
#   'first_name': 'Franz',
#   'last_name': ['Böhm', 'Böhm'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2, 3, 4],
#   'titles': ['Dr.', 'Dr.', 'Dr.', 'Dr.']},
#  {'full_name': ['Fritz Böhm'],
#   'first_name': 'Fritz',
#   'last_name': ['Böhm'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5, 6],
#   'titles': []},
#  {'full_name': ['Hans Böhm', 'Hans Böhm'],
#   'first_name': 'Hans',
#   'last_name': ['Böhm', 'Böhm'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2],
#   'titles': []},
#  {'full_name': ['Wilfried Böhm'],
#   'first_name': 'Wilfried',
#   'last_name': ['Böhm'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [7, 8, 9, 10, 11, 12],
#   'titles': []},
#  {'full_name': ['Georg Böhme'],
#   'first_name': 'Georg',
#   'last_name': ['Böhme'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [4],
#   'titles': []},
#  {'full_name': ['Günter Böhme'],
#   'first_name': 'Günter',
#   'last_name': ['Böhme'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Rolf Böhme'],
#   'first_name': 'Rolf',
#   'last_name': ['Böhme'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [7, 8, 9],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Ulrich Böhme'],
#   'first_name': 'Ulrich',
#   'last_name': ['Böhme'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [11, 12, 13],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Franz Böhner'],
#   'first_name': 'Franz',
#   'last_name': ['Böhner'],
#   'gender': 'male',
#   'party': 'DZP',
#   'periods': [2],
#   'titles': []},
#  {'full_name': ['Holger Börner'],
#   'first_name': 'Holger',
#   'last_name': ['Börner'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3, 4, 5, 6, 7],
#   'titles': []},
#  {'full_name': ['Arne Börnsen'],
#   'first_name': 'Arne',
#   'last_name': ['Börnsen'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [9, 11, 12, 13],
#   'titles': []},
#  {'full_name': ['Wolfgang Börnsen'],
#   'first_name': 'Wolfgang',
#   'last_name': ['Börnsen'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [11, 12, 13, 14, 15, 16, 17],
#   'titles': []},
#  {'full_name': ['Wolfgang Bötsch'],
#   'first_name': 'Wolfgang',
#   'last_name': ['Bötsch'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [8, 9, 10, 11, 12, 13, 14, 15],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Frank Bogisch'],
#   'first_name': 'Frank',
#   'last_name': ['Bogisch'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Friedrich Bohl'],
#   'first_name': 'Friedrich',
#   'last_name': ['Bohl'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [9, 10, 11, 12, 13, 14],
#   'titles': []},
#  {'full_name': ['Wilfried Bohlsen'],
#   'first_name': 'Wilfried',
#   'last_name': ['Bohlsen'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [10, 11, 12],
#   'titles': []},
#  {'full_name': ['Jürgen Bohn'],
#   'first_name': 'Jürgen',
#   'last_name': ['Bohn'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [11],
#   'titles': ['Dr.', 'Dr. - Ing.']},
#  {'full_name': ['Jochen Borchert'],
#   'first_name': 'Jochen',
#   'last_name': ['Borchert'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [9, 10, 11, 12, 13, 14, 15, 16],
#   'titles': []},
#  {'full_name': ['Annemarie Borgmann'],
#   'first_name': 'Annemarie',
#   'last_name': ['Borgmann'],
#   'gender': 'female',
#   'party': 'GRÜNE',
#   'periods': [10],
#   'titles': []},
#  {'full_name': ['William Borm'],
#   'first_name': 'William',
#   'last_name': ['Borm'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [5, 6],
#   'titles': ['Dr.', 'Dr. h. c.']},
#  {'full_name': ['Peter Boroffka'],
#   'first_name': 'Peter',
#   'last_name': ['Boroffka'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [9, 10],
#   'titles': []},
#  {'full_name': ['Lenelotte Bothmer'],
#   'first_name': 'Lenelotte',
#   'last_name': ['Bothmer'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [6, 7, 8],
#   'titles': []},
#  {'full_name': ['Gerhard Botz'],
#   'first_name': 'Gerhard',
#   'last_name': ['Botz'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [11, 16],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Jutta Braband'],
#   'first_name': 'Jutta',
#   'last_name': ['Braband'],
#   'gender': 'female',
#   'party': 'PDS/LL',
#   'periods': [12],
#   'titles': []},
#  {'full_name': ['Klaus Brähmig'],
#   'first_name': 'Klaus',
#   'last_name': ['Brähmig'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [12, 13, 14, 15, 16, 17, 18],
#   'titles': []},
#  {'full_name': ['Hans-Ulrich Brand'],
#   'first_name': 'Hans-Ulrich',
#   'last_name': ['Brand'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [6],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Peter Wilhelm Brand', 'Peter Wilhelm Brand'],
#   'first_name': 'Peter Wilhelm',
#   'last_name': ['Brand', 'Brand'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Bruno Brandes'],
#   'first_name': 'Bruno',
#   'last_name': ['Brandes'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6],
#   'titles': []},
#  {'full_name': ['Hugo Brandt'],
#   'first_name': 'Hugo',
#   'last_name': ['Brandt'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [6, 7, 8, 9],
#   'titles': []},
#  {'full_name': ['Willy Brandt', 'Willy Brandt'],
#   'first_name': 'Willy',
#   'last_name': ['Brandt', 'Brandt'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 4, 6, 7, 8, 9, 10, 11, 12],
#   'titles': []},
#  {'full_name': ['Anni Brandt-Elsweier'],
#   'first_name': 'Anni',
#   'last_name': ['Brandt-Elsweier'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [12, 13, 14],
#   'titles': []},
#  {'full_name': ['Hans-Jochim Brauer'],
#   'first_name': 'Hans-Jochim',
#   'last_name': ['Brauer'],
#   'gender': 'male',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Max Brauer'],
#   'first_name': 'Max',
#   'last_name': ['Brauer'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4],
#   'titles': ['Dr.', 'Dr. h. c.']},
#  {'full_name': ['Aenne Brauksiepe'],
#   'first_name': 'Aenne',
#   'last_name': ['Brauksiepe'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [1, 2, 3, 4, 5, 6],
#   'titles': []},
#  {'full_name': ['Gerhard Braun'],
#   'first_name': 'Gerhard',
#   'last_name': ['Braun'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [7, 8, 9, 10],
#   'titles': []},
#  {'full_name': ['Josef Braun'],
#   'first_name': 'Josef',
#   'last_name': ['Braun'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4, 5],
#   'titles': []},
#  {'full_name': ['Carola Braun-Stützer'],
#   'first_name': 'Carola',
#   'last_name': ['Braun-Stützer'],
#   'gender': 'female',
#   'party': 'FDP',
#   'periods': [9],
#   'titles': []},
#  {'full_name': ['Eberhard Brecht'],
#   'first_name': 'Eberhard',
#   'last_name': ['Brecht'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [12, 13, 14, 19],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Julius Brecht'],
#   'first_name': 'Julius',
#   'last_name': ['Brecht'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3, 4],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Günther Bredehorn'],
#   'first_name': 'Günther',
#   'last_name': ['Bredehorn'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [9, 10, 11, 12, 13],
#   'titles': []},
#  {'full_name': ['Wenzel Bredl'],
#   'first_name': 'Wenzel',
#   'last_name': ['Bredl'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [6, 7],
#   'titles': []},
#  {'full_name': ['Ferdinand Breidbach'],
#   'first_name': 'Ferdinand',
#   'last_name': ['Breidbach'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6, 7, 8],
#   'titles': []},
#  {'full_name': ['Rolf Bremer'],
#   'first_name': 'Rolf',
#   'last_name': ['Bremer'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [5, 6, 7],
#   'titles': []},
#  {'full_name': ['Klaus Bremm'],
#   'first_name': 'Klaus',
#   'last_name': ['Bremm'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6, 7],
#   'titles': []},
#  {'full_name': ['Heinz Brenck'],
#   'first_name': 'Heinz',
#   'last_name': ['Brenck'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [4, 5],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Josef Brenner'],
#   'first_name': 'Josef',
#   'last_name': ['Brenner'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2],
#   'titles': []},
#  {'full_name': ['Heinrich Brentano'],
#   'first_name': 'Heinrich',
#   'last_name': ['Brentano'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3, 4],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Wilhelm Brese'],
#   'first_name': 'Wilhelm',
#   'last_name': ['Brese'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Paul Breuer'],
#   'first_name': 'Paul',
#   'last_name': ['Breuer'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [9, 10, 11, 12, 13, 14, 15],
#   'titles': []},
#  {'full_name': ['Ulrich Briefs'],
#   'first_name': 'Ulrich',
#   'last_name': ['Briefs'],
#   'gender': 'male',
#   'party': 'PDS/LL',
#   'periods': [11, 12],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Hermann Louis Brill'],
#   'first_name': 'Hermann Louis',
#   'last_name': ['Brill'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Johannes Brockmann'],
#   'first_name': 'Johannes',
#   'last_name': ['Brockmann'],
#   'gender': 'male',
#   'party': 'DZP',
#   'periods': [2],
#   'titles': []},
#  {'full_name': ['Else Brökelschen'],
#   'first_name': 'Else',
#   'last_name': ['Brökelschen'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [1, 2, 3],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Josef Brönner'],
#   'first_name': 'Josef',
#   'last_name': ['Brönner'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Werner Broll'],
#   'first_name': 'Werner',
#   'last_name': ['Broll'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [8, 9, 10],
#   'titles': []},
#  {'full_name': ['Paul Bromme'],
#   'first_name': 'Paul',
#   'last_name': ['Bromme'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Walter Brookmann', 'Walter Brookmann'],
#   'first_name': 'Walter',
#   'last_name': ['Brookmann', 'Brookmann'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2],
#   'titles': []},
#  {'full_name': ['Gerhard Brosi'],
#   'first_name': 'Gerhard',
#   'last_name': ['Brosi'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [10],
#   'titles': []},
#  {'full_name': ['Monika Brudlewsky'],
#   'first_name': 'Monika',
#   'last_name': ['Brudlewsky'],
#   'gender': 'female',
#   'party': 'CDU',
# ...
#   'first_name': 'Egon',
#   'last_name': ['Höhmann', 'Höhmann'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3, 4, 5, 6, 7, 8],
#   'titles': []},
#  {'full_name': ['Franz Höhne'],
#   'first_name': 'Franz',
#   'last_name': ['Höhne'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Barbara Höll'],
#   'first_name': 'Barbara',
#   'last_name': ['Höll'],
#   'gender': 'female',
#   'party': 'DIE LINKE.',
#   'periods': [12, 13, 14, 16, 17],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Friedrich Hölscher'],
#   'first_name': 'Friedrich',
#   'last_name': ['Hölscher'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [7, 8, 9],
#   'titles': []},
#  {'full_name': ['Ernst Hölzle'],
#   'first_name': 'Ernst',
#   'last_name': ['Hölzle'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5],
#   'titles': []},
#  {'full_name': ['Hannegret Hönes'],
#   'first_name': 'Hannegret',
#   'last_name': ['Hönes'],
#   'gender': 'female',
#   'party': 'GRÜNE',
#   'periods': [10],
#   'titles': []},
#  {'full_name': ['Bertram Hönicke'],
#   'first_name': 'Bertram',
#   'last_name': ['Hönicke'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Stefan Höpfinger'],
#   'first_name': 'Stefan',
#   'last_name': ['Höpfinger'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [8, 9, 10, 11],
#   'titles': []},
#  {'full_name': ['Hermann Höpker-Aschoff'],
#   'first_name': 'Hermann',
#   'last_name': ['Höpker-Aschoff'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [1],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Fritz Wilhelm Hörauf'],
#   'first_name': 'Fritz Wilhelm',
#   'last_name': ['Hörauf'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Hans Hörmann'],
#   'first_name': 'Hans',
#   'last_name': ['Hörmann'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4, 5, 6],
#   'titles': []},
#  {'full_name': ['Heinrich Hörnemann'],
#   'first_name': 'Heinrich',
#   'last_name': ['Hörnemann'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [4, 5],
#   'titles': []},
#  {'full_name': ['Heinz-Adolf Hörsken'],
#   'first_name': 'Heinz-Adolf',
#   'last_name': ['Hörsken'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [12, 13],
#   'titles': []},
#  {'full_name': ['Joachim Hörster'],
#   'first_name': 'Joachim',
#   'last_name': ['Hörster'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [11, 12, 13, 14, 15, 16, 17],
#   'titles': []},
#  {'full_name': ['Alex Hösl'],
#   'first_name': 'Alex',
#   'last_name': ['Hösl'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [4, 5, 6, 7, 8],
#   'titles': []},
#  {'full_name': ['Paul Hoffacker'],
#   'first_name': 'Paul',
#   'last_name': ['Hoffacker'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [8, 9, 10, 11, 12],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Klaus-Jürgen Hoffie'],
#   'first_name': 'Klaus-Jürgen',
#   'last_name': ['Hoffie'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [7, 8, 9, 10],
#   'titles': []},
#  {'full_name': ['Curt Hoffmann'],
#   'first_name': 'Curt',
#   'last_name': ['Hoffmann'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [1],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Hans-Joachim Hoffmann'],
#   'first_name': 'Hans-Joachim',
#   'last_name': ['Hoffmann'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [8, 9, 10],
#   'titles': []},
#  {'full_name': ['Ingeborg Hoffmann', 'Ingeborg Hoffmann'],
#   'first_name': 'Ingeborg',
#   'last_name': ['Hoffmann', 'Hoffmann'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [8, 9, 10, 11],
#   'titles': []},
#  {'full_name': ['Johannes Hoffmann'],
#   'first_name': 'Johannes',
#   'last_name': ['Hoffmann'],
#   'gender': 'male',
#   'party': 'FU',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Karl Hoffmann'],
#   'first_name': 'Karl',
#   'last_name': ['Hoffmann'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [1, 2],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Josef Hofmann'],
#   'first_name': 'Josef',
#   'last_name': ['Hofmann'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [5],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Karl Hofmann', 'Karl Hofmann', 'Karl Hofmann'],
#   'first_name': 'Karl',
#   'last_name': ['Hofmann', 'Hofmann', 'Hofmann'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5, 6, 7, 8, 9],
#   'titles': []},
#  {'full_name': ['Heinrich Hohl'],
#   'first_name': 'Heinrich',
#   'last_name': ['Hohl'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Heinrich Holkenbrink'],
#   'first_name': 'Heinrich',
#   'last_name': ['Holkenbrink'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [4, 5],
#   'titles': []},
#  {'full_name': ['Ernst Holla'],
#   'first_name': 'Ernst',
#   'last_name': ['Holla'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2, 3],
#   'titles': []},
#  {'full_name': ['Josef Hollerith'],
#   'first_name': 'Josef',
#   'last_name': ['Hollerith'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [12, 13, 14],
#   'titles': []},
#  {'full_name': ['Erwin Holsteg'],
#   'first_name': 'Erwin',
#   'last_name': ['Holsteg'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [9],
#   'titles': []},
#  {'full_name': ['Uwe Holtz'],
#   'first_name': 'Uwe',
#   'last_name': ['Holtz'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [7, 8, 9, 10, 11, 12],
#   'titles': ['Dr.', 'Prof. Dr.']},
#  {'full_name': ['Joachim Holz'],
#   'first_name': 'Joachim',
#   'last_name': ['Holz'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Friedrich Holzapfel'],
#   'first_name': 'Friedrich',
#   'last_name': ['Holzapfel'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Lieselotte Holzmeister'],
#   'first_name': 'Lieselotte',
#   'last_name': ['Holzmeister'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [5],
#   'titles': []},
#  {'full_name': ['Birgit Homburger'],
#   'first_name': 'Birgit',
#   'last_name': ['Homburger'],
#   'gender': 'female',
#   'party': 'FDP',
#   'periods': [12, 13, 14, 15, 16, 17],
#   'titles': []},
#  {'full_name': ['Matthias Hoogen'],
#   'first_name': 'Matthias',
#   'last_name': ['Hoogen'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3, 4],
#   'titles': []},
#  {'full_name': ['Anton Hoppe'],
#   'first_name': 'Anton',
#   'last_name': ['Hoppe'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Hans-Günter Hoppe'],
#   'first_name': 'Hans-Günter',
#   'last_name': ['Hoppe'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [7, 8, 9, 10, 11],
#   'titles': []},
#  {'full_name': ['Milan Horacek'],
#   'first_name': 'Milan',
#   'last_name': ['Horacek'],
#   'gender': 'male',
#   'party': 'GRÜNE',
#   'periods': [10],
#   'titles': []},
#  {'full_name': ['Michael Horlacher'],
#   'first_name': 'Michael',
#   'last_name': ['Horlacher'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [1, 2],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Erwin Horn'],
#   'first_name': 'Erwin',
#   'last_name': ['Horn'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [6, 7, 8, 9, 10, 11, 12, 13],
#   'titles': []},
#  {'full_name': ['Peter Horn'],
#   'first_name': 'Peter',
#   'last_name': ['Horn'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3, 4],
#   'titles': []},
#  {'full_name': ['Karl-Heinz Hornhues'],
#   'first_name': 'Karl-Heinz',
#   'last_name': ['Hornhues'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [7, 8, 9, 10, 11, 12, 13, 14],
#   'titles': ['Dr.', 'Prof. Dr.']},
#  {'full_name': ['Siegfried Hornung'],
#   'first_name': 'Siegfried',
#   'last_name': ['Hornung'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [10, 11, 12, 13, 14],
#   'titles': []},
#  {'full_name': ['Martin Horstmeier'],
#   'first_name': 'Martin',
#   'last_name': ['Horstmeier'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [5, 6, 7, 8, 9, 10],
#   'titles': []},
#  {'full_name': ['Alphons Horten'],
#   'first_name': 'Alphons',
#   'last_name': ['Horten'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [5, 6],
#   'titles': []},
#  {'full_name': ['Willi Hoss'],
#   'first_name': 'Willi',
#   'last_name': ['Hoss'],
#   'gender': 'male',
#   'party': 'DIE GRÜNEN/BÜNDNIS 90',
#   'periods': [10, 11],
#   'titles': []},
#  {'full_name': ['Sigrid Hoth'],
#   'first_name': 'Sigrid',
#   'last_name': ['Hoth'],
#   'gender': 'female',
#   'party': 'FDP',
#   'periods': [12],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Viktor Hoven'],
#   'first_name': 'Viktor',
#   'last_name': ['Hoven'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [3, 4],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Werner Hoyer'],
#   'first_name': 'Werner',
#   'last_name': ['Hoyer'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [11, 12, 13, 14, 15, 16, 17],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Antje Huber'],
#   'first_name': 'Antje',
#   'last_name': ['Huber'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [6, 7, 8, 9, 10],
#   'titles': []},
#  {'full_name': ['Elinor Hubert'],
#   'first_name': 'Elinor',
#   'last_name': ['Hubert'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4, 5],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Hans Hubrig'],
#   'first_name': 'Hans',
#   'last_name': ['Hubrig'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6, 8, 9],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Adalbert Hudak'],
#   'first_name': 'Adalbert',
#   'last_name': ['Hudak'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [5],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Heinz Werner Hübner'],
#   'first_name': 'Heinz Werner',
#   'last_name': ['Hübner'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [12],
#   'titles': []},
#  {'full_name': ['Karl Hübner'],
#   'first_name': 'Karl',
#   'last_name': ['Hübner'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [1, 2, 3, 4],
#   'titles': []},
#  {'full_name': ['Klaus Hübner'],
#   'first_name': 'Klaus',
#   'last_name': ['Hübner'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4, 5],
#   'titles': []},
#  {'full_name': ['Hubert Hüppe'],
#   'first_name': 'Hubert',
#   'last_name': ['Hüppe'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [12, 13, 14, 15, 16, 17, 18, 20],
#   'titles': []},
#  {'full_name': ['Agnes Hürland', 'Agnes Hürland-Büning'],
#   'first_name': 'Agnes',
#   'last_name': ['Hürland', 'Hürland-Büning'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [7, 8, 9, 10, 11],
#   'titles': []},
#  {'full_name': ['Heinz Günther Hüsch'],
#   'first_name': 'Heinz Günther',
#   'last_name': ['Hüsch'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [8, 9, 10, 11],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Uwe Hüser'],
#   'first_name': 'Uwe',
#   'last_name': ['Hüser'],
#   'gender': 'male',
#   'party': 'BÜNDNIS 90/DIE GRÜNEN',
#   'periods': [11],
#   'titles': []},
#  {'full_name': ['Margarete Hütter'],
#   'first_name': 'Margarete',
#   'last_name': ['Hütter'],
#   'gender': 'female',
#   'party': 'FDP',
#   'periods': [1, 2],
#   'titles': []},
#  {'full_name': ['Josef Hufnagel'],
#   'first_name': 'Josef',
#   'last_name': ['Hufnagel'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Gunter Huonker'],
#   'first_name': 'Gunter',
#   'last_name': ['Huonker'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [7, 8, 9, 10, 11, 12],
#   'titles': []},
#  {'full_name': ['Herbert Hupka'],
#   'first_name': 'Herbert',
#   'last_name': ['Hupka'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6, 7, 8, 9, 10],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Dieter Hussing'],
#   'first_name': 'Dieter',
#   'last_name': ['Hussing'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [6, 7],
#   'titles': []},
#  {'full_name': ['Rudolf Hussong'],
#   'first_name': 'Rudolf',
#   'last_name': ['Hussong'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [4, 5],
#   'titles': []},
#  {'full_name': ['Eugen Huth'],
#   'first_name': 'Eugen',
#   'last_name': ['Huth'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [1, 2, 3],
#   'titles': []},
#  {'full_name': ['Eugen Huthmacher'],
#   'first_name': 'Eugen',
#   'last_name': ['Huthmacher'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [4],
#   'titles': []},
#  {'full_name': ['Hans Huyn'],
#   'first_name': 'Hans',
#   'last_name': ['Huyn'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [8, 9, 10, 11],
#   'titles': []},
#  {'full_name': ['Lambert Huys'],
#   'first_name': 'Lambert',
#   'last_name': ['Huys'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [3, 4, 5, 6],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Lothar Ibrügger'],
#   'first_name': 'Lothar',
#   'last_name': ['Ibrügger'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [8, 9, 10, 11, 12, 13, 14, 15, 16],
#   'titles': []},
#  {'full_name': ['Herta Ilk'],
#   'first_name': 'Herta',
#   'last_name': ['Ilk'],
#   'gender': 'female',
#   'party': 'FDP',
#   'periods': [1, 2],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Joseph Illerhaus'],
#   'first_name': 'Joseph',
#   'last_name': ['Illerhaus'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [2, 3, 4, 5],
#   'titles': []},
#  {'full_name': ['Hans Ils'],
#   'first_name': 'Hans',
#   'last_name': ['Ils'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [5],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Heinrich Imig'],
#   'first_name': 'Heinrich',
#   'last_name': ['Imig'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Wolfgang Imle'],
#   'first_name': 'Wolfgang',
#   'last_name': ['Imle'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [3, 4, 5],
#   'titles': ['Dr.', 'Dr.']},
#  {'full_name': ['Klaus Immer'],
#   'first_name': 'Klaus',
#   'last_name': ['Immer'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [7, 8, 9, 10],
#   'titles': []},
#  {'full_name': ['Ulrich Irmer'],
#   'first_name': 'Ulrich',
#   'last_name': ['Irmer'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [11, 12, 13, 14],
#   'titles': []},
#  {'full_name': ['Hans Iven', 'Hans Iven'],
#   'first_name': 'Hans',
#   'last_name': ['Iven', 'Iven'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [3, 4, 5],
#   'titles': []},
#  {'full_name': ['Gabriele Iwersen'],
#   'first_name': 'Gabriele',
#   'last_name': ['Iwersen'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [12, 13, 14],
#   'titles': []},
#  {'full_name': ['Maria Jacobi'],
#   'first_name': 'Maria',
#   'last_name': ['Jacobi'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [4, 5, 6],
#   'titles': []},
#  {'full_name': ['Werner Jacobi', 'Werner Jacobi', 'Werner Jacobi'],
#   'first_name': 'Werner',
#   'last_name': ['Jacobi', 'Jacobi', 'Jacobi'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4, 5, 6],
#   'titles': []},
#  {'full_name': ['Peter Jacobs'],
#   'first_name': 'Peter',
#   'last_name': ['Jacobs'],
#   'gender': 'male',
#   'party': 'SPD',
#   'periods': [1, 2, 3, 4],
#   'titles': []},
#  {'full_name': ['Claus Jäger', 'Claus Jäger'],
#   'first_name': 'Claus',
#   'last_name': ['Jäger', 'Jäger'],
#   'gender': 'male',
#   'party': 'CDU',
#   'periods': [7, 8, 9, 10, 11, 12],
#   'titles': []},
#  {'full_name': ['Renate Jäger'],
#   'first_name': 'Renate',
#   'last_name': ['Jäger'],
#   'gender': 'female',
#   'party': 'SPD',
#   'periods': [12, 13, 14, 15],
#   'titles': []},
#  {'full_name': ['Elfriede Jaeger'],
#   'first_name': 'Elfriede',
#   'last_name': ['Jaeger'],
#   'gender': 'female',
#   'party': 'DRP',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Paul Hans Jaeger'],
#   'first_name': 'Paul Hans',
#   'last_name': ['Jaeger'],
#   'gender': 'male',
#   'party': 'FDP',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Richard Jaeger', 'Richard Jaeger'],
#   'first_name': 'Richard',
#   'last_name': ['Jaeger', 'Jaeger'],
#   'gender': 'male',
#   'party': 'CSU',
#   'periods': [1, 2, 3, 4, 5, 6, 7, 8],
#   'titles': ['Dr.', 'Dr.', 'Dr.', 'Dr.']},
#  {'full_name': ['Robert Jaffe'],
#   'first_name': 'Robert',
#   'last_name': ['Jaffe'],
#   'gender': 'male',
#   'party': 'DP',
#   'periods': [1],
#   'titles': []},
#  {'full_name': ['Susanne Jaffke', 'Susanne Jaffke-Witt'],
#   'first_name': 'Susanne',
#   'last_name': ['Jaffke', 'Jaffke-Witt'],
#   'gender': 'female',
#   'party': 'CDU',
#   'periods': [11, 12, 13, 14, 15, 16],
#   'titles': []},
#  ...]

# %%
# number of unique speakers
df['speaker_id'].nunique()
# Out:
# 4713

# %%
# compare members in original data with new member data and find deviations
no_name_matches = []
no_gender_matches = []
name_matches = []

faulty_names = [961, 348, 790]

for speaker_id in df['speaker_id'].unique():
    name = df.loc[df['speaker_id'] == speaker_id, 'speaker_name'].iloc[0]

    if speaker_id in faulty_names:
        without_ws = re.sub('(\s){1,}', '', name)
        name = re.sub(r"(\w)([A-Z])", r"\1 \2", without_ws)

    splitted_name = name.split()

    gender = df.loc[df['speaker_id'] == speaker_id, 'speaker_gender'].iloc[0]

    found_matching_member = False

    # iterate through member data
    for member in member_data:
        real_names = member['full_name']
        real_gender = member['gender']
        periods = member['periods']
        
        split_names = [name.split() for name in real_names]
        flat_names = [item for sublist in split_names for item in sublist]
        unique_names = list(set(flat_names))

        if len(set(unique_names) & set(splitted_name)) >= 2:
            found_matching_member = True
            print(f"Match found for df_speaker {name} and real speaker {real_names}")
            name_matches.append(speaker_id)

            if not gender == real_gender:
                #print(f"No correct gender for {name}")
                no_gender_matches.append(speaker_id)
    
    if not found_matching_member:
        no_name_matches.append(speaker_id)
        print(f"No match found for df_speaker {name} and real speaker {real_names}")
# Out:
# Match found for df_speaker Gabriele Katzmarek and real speaker ['Gabriele Katzmarek']
# Match found for df_speaker Stefan Müller and real speaker ['Stefan Müller']
# Match found for df_speaker Britta Haßelmann and real speaker ['Britta Haßelmann']
# Match found for df_speaker Marco Buschmann and real speaker ['Marco Buschmann']
# Match found for df_speaker Stephan Brandner and real speaker ['Stephan Brandner']
# Match found for df_speaker Jan Korte and real speaker ['Jan Korte']
# Match found for df_speaker Rolf Mützenich and real speaker ['Rolf Mützenich']
# Match found for df_speaker Bärbel Bas and real speaker ['Bärbel Bas']
# Match found for df_speaker Fabian Jacobi and real speaker ['Fabian Jacobi']
# Match found for df_speaker Aydan Özoğuz and real speaker ['Aydan Özoğuz']
# Match found for df_speaker Yvonne Magwas and real speaker ['Yvonne Magwas']
# Match found for df_speaker Claudia Roth and real speaker ['Claudia Roth']
# Match found for df_speaker Wolfgang Kubicki and real speaker ['Wolfgang Kubicki']
# Match found for df_speaker Petra Pau and real speaker ['Petra Pau']
# Match found for df_speaker Marianne Schieder and real speaker ['Marianne Schieder', 'Marianne Schieder']
# Match found for df_speaker Michael Grosse-Brömer and real speaker ['Michael Grosse-Brömer']
# Match found for df_speaker Bettina Stark-Watzinger and real speaker ['Bettina Stark-Watzinger']
# Match found for df_speaker Olaf Scholz and real speaker ['Olaf Scholz']
# Match found for df_speaker Thomas Ehrhorn and real speaker ['Thomas Ehrhorn']
# Match found for df_speaker Ralph Brinkhaus and real speaker ['Ralph Brinkhaus']
# Match found for df_speaker Katrin Göring-Eckardt and real speaker ['Katrin Dagmar Göring-Eckardt', 'Katrin Göring-Eckardt']
# Match found for df_speaker Sebastian Münzenmaier and real speaker ['Sebastian Münzenmaier']
# Match found for df_speaker Susanne Ferschl and real speaker ['Susanne Ferschl']
# Match found for df_speaker Dirk Wiese and real speaker ['Dirk Wiese']
# Match found for df_speaker Alexander Dobrindt and real speaker ['Alexander Dobrindt']
# Match found for df_speaker Maria Klein-Schmeink and real speaker ['Maria Klein-Schmeink']
# Match found for df_speaker Christine Aschenberg-Dugnus and real speaker ['Christine Aschenberg-Dugnus']
# Match found for df_speaker Jörg Schneider and real speaker ['Jörg Schneider']
# Match found for df_speaker Jan-Marco Luczak and real speaker ['Jan-Marco Luczak']
# Match found for df_speaker Sabine Dittmar and real speaker ['Sabine Dittmar']
# Match found for df_speaker Nina Warken and real speaker ['Nina Warken', 'Nina Warken']
# Match found for df_speaker Thorsten Frei and real speaker ['Thorsten Frei']
# Match found for df_speaker Heiko Maas and real speaker ['Heiko Maas']
# Match found for df_speaker Franziska Brantner and real speaker ['Franziska Brantner']
# No match found for df_speaker Joachim Stamp and real speaker ['Christian Bartelt']
# Match found for df_speaker Gottfried Curio and real speaker ['Gottfried Curio']
# Match found for df_speaker Gökay Akbulut and real speaker ['Gökay Akbulut']
# Match found for df_speaker Markus Frohnmaier and real speaker ['Markus Frohnmaier']
# Match found for df_speaker Johann David Wadephul and real speaker ['Johann Wadephul', 'Johann David Wadephul']
# Match found for df_speaker Lars Castellucci and real speaker ['Lars Castellucci']
# Match found for df_speaker Zaklin Nastic and real speaker ['Zaklin Nastic']
# Match found for df_speaker Andrea Lindholz and real speaker ['Andrea Lindholz']
# Match found for df_speaker Julian Pahlke and real speaker ['Julian Pahlke']
# Match found for df_speaker Lisa Paus and real speaker ['Lisa Paus']
# Match found for df_speaker Sarah Ryglewski and real speaker ['Sarah Ryglewski']
# Match found for df_speaker Antje Tillmann and real speaker ['Antje Tillmann']
# Match found for df_speaker Till Mansmann and real speaker ['Till Mansmann']
# Match found for df_speaker Klaus Stöber and real speaker ['Klaus Stöber']
# Match found for df_speaker Christian Görke and real speaker ['Christian Görke']
# Match found for df_speaker Cansel Kiziltepe and real speaker ['Cansel Kiziltepe']
# Match found for df_speaker Fritz Güntzler and real speaker ['Fritz Güntzler']
# Match found for df_speaker Karsten Hilse and real speaker ['Karsten Hilse']
# Match found for df_speaker Timon Gremmels and real speaker ['Timon Gremmels']
# Match found for df_speaker Mark Helfrich and real speaker ['Mark Helfrich']
# Match found for df_speaker Julia Verlinden and real speaker ['Julia Verlinden']
# Match found for df_speaker Rainer Kraft and real speaker ['Rainer Kraft']
# Match found for df_speaker Reinhard Houben and real speaker ['Reinhard Houben']
# Match found for df_speaker Ralph Lenkert and real speaker ['Ralph Lenkert']
# Match found for df_speaker Nina Scheer and real speaker ['Nina Scheer']
# Match found for df_speaker Andreas Lenz and real speaker ['Andreas Lenz']
# Match found for df_speaker Gesine Lötzsch and real speaker ['Gesine Lötzsch']
# Match found for df_speaker Bernhard Daldrup and real speaker ['Bernhard Daldrup']
# Match found for df_speaker Kai Whittaker and real speaker ['Kai Whittaker']
# Match found for df_speaker Christian Kühn and real speaker ['Christian Kühn']
# Match found for df_speaker Daniel Föst and real speaker ['Daniel Föst']
# Match found for df_speaker Marc Bernhard and real speaker ['Marc Bernhard']
# Match found for df_speaker Kevin Kühnert and real speaker ['Kevin Kühnert']
# Match found for df_speaker Peter Aumer and real speaker ['Peter Aumer']
# Match found for df_speaker Anja Weisgerber and real speaker ['Anja Weisgerber']
# Match found for df_speaker Carsten Träger and real speaker ['Carsten Träger']
# Match found for df_speaker Oliver Krischer and real speaker ['Oliver Krischer']
# Match found for df_speaker Lukas Köhler and real speaker ['Lukas Köhler']
# Match found for df_speaker Steffen Kotré and real speaker ['Steffen Kotré']
# Match found for df_speaker Amira Mohamed Ali and real speaker ['Amira Mohamed Ali']
# Match found for df_speaker Christoph Ploß and real speaker ['Christoph Ploß']
# Match found for df_speaker Jürgen Trittin and real speaker ['Jürgen Trittin']
# Match found for df_speaker Judith Skudelny and real speaker ['Judith Skudelny']
# Match found for df_speaker Stephan Stracke and real speaker ['Stephan Stracke']
# Match found for df_speaker Tino Chrupalla and real speaker ['Tino Chrupalla']
# Match found for df_speaker Dietmar Bartsch and real speaker ['Dietmar Bartsch']
# Match found for df_speaker Johannes Fechner and real speaker ['Johannes Fechner']
# Match found for df_speaker Norbert Kleinwächter and real speaker ['Norbert Kleinwächter']
# Match found for df_speaker Manuela Rottmann and real speaker ['Manuela Rottmann']
# Match found for df_speaker Jens Spahn and real speaker ['Jens Spahn']
# Match found for df_speaker Michael Theurer and real speaker ['Michael Theurer']
# Match found for df_speaker Martin Sichert and real speaker ['Martin Sichert']
# Match found for df_speaker Heike Baehrens and real speaker ['Heike Baehrens']
# Match found for df_speaker Katja Leikert and real speaker ['Katja Leikert']
# Match found for df_speaker Detlef Müller and real speaker ['Detlef Müller']
# Match found for df_speaker René Bochmann and real speaker ['René Bochmann']
# Match found for df_speaker Silke Launert and real speaker ['Silke Launert']
# Match found for df_speaker Ulrike Bahr and real speaker ['Ulrike Bahr']
# Match found for df_speaker Ekin Deligöz and real speaker ['Ekin Deligöz']
# Match found for df_speaker Peter Heidt and real speaker ['Peter Heidt']
# Match found for df_speaker Nicole Höchst and real speaker ['Nicole Höchst']
# Match found for df_speaker Nicole Gohlke and real speaker ['Nicole Gohlke']
# Match found for df_speaker Silvia Breher and real speaker ['Silvia Breher']
# Match found for df_speaker Marja-Liisa Völlers and real speaker ['Marja-Liisa Völlers']
# Match found for df_speaker Christian Haase and real speaker ['Christian Haase']
# Match found for df_speaker Dietrich Monstadt and real speaker ['Dietrich Monstadt']
# Match found for df_speaker Karsten Klein and real speaker ['Karsten Klein']
# Match found for df_speaker Kay-Uwe Ziegler and real speaker ['Kay-Uwe Ziegler']
# Match found for df_speaker Stephan Pilsinger and real speaker ['Stephan Pilsinger']
# Match found for df_speaker Sebastian Brehm and real speaker ['Sebastian Brehm']
# Match found for df_speaker Ophelia Nick and real speaker ['Ophelia Nick']
# Match found for df_speaker Susanne Mittag and real speaker ['Susanne Mittag']
# Match found for df_speaker Kay Gottschalk and real speaker ['Kay Gottschalk']
# Match found for df_speaker Artur Auernhammer and real speaker ['Artur Auernhammer']
# Match found for df_speaker Martin Hess and real speaker ['Martin Hess']
# No match found for df_speaker Ulrich Grötsch and real speaker ['Christian Bartelt']
# Match found for df_speaker Mathias Middelberg and real speaker ['Mathias Middelberg']
# Match found for df_speaker Omid Nouripour and real speaker ['Omid Nouripour']
# Match found for df_speaker Linda Teuteberg and real speaker ['Linda Teuteberg']
# Match found for df_speaker Frank Schwabe and real speaker ['Frank Schwabe']
# Match found for df_speaker Elisabeth Kaiser and real speaker ['Elisabeth Kaiser']
# Match found for df_speaker Thomas Erndl and real speaker ['Thomas Erndl']
# Match found for df_speaker Katrin Staffler and real speaker ['Katrin Staffler']
# Match found for df_speaker Kai Gehring and real speaker ['Kai Gehring']
# Match found for df_speaker Jens Brandenburg and real speaker ['Jens Brandenburg']
# Match found for df_speaker Götz Frömming and real speaker ['Götz Frömming']
# Match found for df_speaker Jessica Rosenthal and real speaker ['Jessica Rosenthal']
# Match found for df_speaker Stephan Albani and real speaker ['Stephan Albani']
# Match found for df_speaker Andreas Audretsch and real speaker ['Andreas Audretsch']
# Match found for df_speaker Markus Herbrand and real speaker ['Markus Herbrand']
# Match found for df_speaker Sven-Christian Kindler and real speaker ['Sven-Christian Kindler']
# Match found for df_speaker Alice Weidel and real speaker ['Alice Weidel']
# Match found for df_speaker Janosch Dahmen and real speaker ['Janosch Dahmen']
# Match found for df_speaker Katrin Helling-Plahr and real speaker ['Katrin Helling-Plahr']
# Match found for df_speaker Christina Baum and real speaker ['Christina Baum']
# Match found for df_speaker Matthias Helferich and real speaker ['Matthias Helferich']
# Match found for df_speaker Tino Sorge and real speaker ['Tino Sorge']
# Match found for df_speaker Michael Gerdes and real speaker ['Michael Gerdes']
# Match found for df_speaker Robert Habeck and real speaker ['Robert Habeck']
# Match found for df_speaker Christian Lindner and real speaker ['Christian Lindner']
# No match found for df_speaker Nancy Faeser and real speaker ['Christian Bartelt']
# Match found for df_speaker Annalena Baerbock and real speaker ['Annalena Baerbock']
# Match found for df_speaker Hubertus Heil and real speaker ['Hubertus Heil']
# Match found for df_speaker Christine Lambrecht and real speaker ['Christine Lambrecht']
# Match found for df_speaker Cem Özdemir and real speaker ['Cem Özdemir']
# No match found for df_speaker Anne Spiegel and real speaker ['Christian Bartelt']
# Match found for df_speaker Karl Lauterbach and real speaker ['Karl Lauterbach']
# Match found for df_speaker Volker Wissing and real speaker ['Volker Wissing']
# Match found for df_speaker Steffi Lemke and real speaker ['Steffi Lemke']
# Match found for df_speaker Svenja Schulze and real speaker ['Svenja Schulze']
# No match found for df_speaker Klara Geywitz and real speaker ['Christian Bartelt']
# Match found for df_speaker Wolfgang Schmidt and real speaker ['Wolfgang Schmidt']
# Match found for df_speaker Otto Fricke and real speaker ['Otto Fricke']
# Match found for df_speaker Andreas Jung and real speaker ['Andreas Jung', 'Andreas Jung']
# Match found for df_speaker Andreas Schwarz and real speaker ['Andreas Schwarz']
# Match found for df_speaker Peter Boehringer and real speaker ['Peter Boehringer']
# Match found for df_speaker Victor Perli and real speaker ['Victor Perli']
# Match found for df_speaker Carsten Müller and real speaker ['Carsten Müller']
# Match found for df_speaker Bernd Westphal and real speaker ['Bernd Westphal']
# Match found for df_speaker Florian Oßner and real speaker ['Florian Oßner']
# Match found for df_speaker Felix Schreiner and real speaker ['Felix Schreiner']
# Match found for df_speaker Johann Saathoff and real speaker ['Johann Saathoff']
# Match found for df_speaker Dirk Spaniel and real speaker ['Dirk Spaniel']
# Match found for df_speaker Stefan Gelbhaar and real speaker ['Stefan Gelbhaar']
# Match found for df_speaker Thomas Lutze and real speaker ['Thomas Lutze']
# Match found for df_speaker Bernd Reuther and real speaker ['Bernd Reuther']
# Match found for df_speaker Wiebke Esdar and real speaker ['Wiebke Esdar']
# Match found for df_speaker Matthias Gastel and real speaker ['Matthias Gastel']
# Match found for df_speaker Alois Rainer and real speaker ['Alois Rainer']
# Match found for df_speaker Alois Rainer and real speaker ['Alois Rainer']
# Match found for df_speaker Nadine Schön and real speaker ['Nadine Müller', 'Nadine Schön', 'Nadine Schön']
# Match found for df_speaker Sönke Rix and real speaker ['Sönke Rix']
# Match found for df_speaker Martin Reichardt and real speaker ['Martin Reichardt']
# Match found for df_speaker Matthias Seestern-Pauly and real speaker ['Matthias Seestern-Pauly']
# Match found for df_speaker Oliver Kaczmarek and real speaker ['Oliver Kaczmarek']
# Match found for df_speaker Ulrike Schielke-Ziesing and real speaker ['Ulrike Schielke-Ziesing']
# Match found for df_speaker Hermann-Josef Tebroke and real speaker ['Hermann-Josef Tebroke']
# Match found for df_speaker Jessica Tatti and real speaker ['Jessica Tatti']
# Match found for df_speaker Pascal Kober and real speaker ['Pascal Kober']
# Match found for df_speaker Martin Rosemann and real speaker ['Martin Rosemann']
# Match found for df_speaker Klaus Wiener and real speaker ['Klaus Wiener']
# Match found for df_speaker Johannes Steiniger and real speaker ['Johannes Steiniger']
# Match found for df_speaker Kathrin Vogler and real speaker ['Kathrin Vogler']
# Match found for df_speaker Michael Hennrich and real speaker ['Michael Hennrich']
# Match found for df_speaker Andrew Ullmann and real speaker ['Andrew Ullmann']
# Match found for df_speaker Martina Stamm-Fibich and real speaker ['Martina Stamm-Fibich']
# Match found for df_speaker Nils Schmid and real speaker ['Nils Schmid']
# Match found for df_speaker Alexander Gauland and real speaker ['Alexander Gauland']
# Match found for df_speaker Ali Al-Dailami and real speaker ['Ali Al-Dailami']
# Match found for df_speaker Alexander Graf Lambsdorff and real speaker ['Alexander Lambsdorff']
# Match found for df_speaker Christian Petry and real speaker ['Christian Petry']
# Match found for df_speaker Jürgen Hardt and real speaker ['Jürgen Hardt']
# Match found for df_speaker Robin Wagener and real speaker ['Robin Wagener']
# Match found for df_speaker Michael Georg Link and real speaker ['Michael Link', 'Michael Georg Link']
# Match found for df_speaker Wolfgang Hellmich and real speaker ['Wolfgang Hellmich']
# Match found for df_speaker Erwin Rüddel and real speaker ['Erwin Rüddel']
# Match found for df_speaker Volker Ullrich and real speaker ['Volker Ullrich']
# Match found for df_speaker Bernd Rützel and real speaker ['Bernd Rützel']
# Match found for df_speaker Hendrik Hoppenstedt and real speaker ['Hendrik Hoppenstedt']
# Match found for df_speaker Katja Adler and real speaker ['Katja Adler']
# Match found for df_speaker Matthias W. Birkwald and real speaker ['Matthias W. Birkwald']
# Match found for df_speaker Simone Borchardt and real speaker ['Simone Borchardt']
# Match found for df_speaker Mario Brandenburg and real speaker ['Mario Brandenburg']
# Match found for df_speaker Carsten Brodesser and real speaker ['Carsten Brodesser']
# Match found for df_speaker Michael Donth and real speaker ['Michael Donth']
# Match found for df_speaker Fabian Gramling and real speaker ['Fabian Gramling']
# Match found for df_speaker Andrej Hunko and real speaker ['Andrej Hunko']
# Match found for df_speaker Ronja Kemmer and real speaker ['Ronja Schmitt', 'Ronja Kemmer']
# Match found for df_speaker Tilman Kuban and real speaker ['Tilman Kuban']
# Match found for df_speaker Thorsten Lieb and real speaker ['Thorsten Lieb']
# Match found for df_speaker Alexander Müller and real speaker ['Alexander Müller']
# Match found for df_speaker Frank Müller-Rosentritt and real speaker ['Frank Müller-Rosentritt']
# Match found for df_speaker Wilfried Oellers and real speaker ['Wilfried Oellers']
# Match found for df_speaker Henning Rehbaum and real speaker ['Henning Rehbaum']
# Match found for df_speaker Josef Rief and real speaker ['Josef Rief']
# Match found for df_speaker Christian Sauter and real speaker ['Christian Sauter']
# Match found for df_speaker Jana Schimke and real speaker ['Jana Schimke']
# Match found for df_speaker Stefan Seidler and real speaker ['Stefan Seidler']
# Match found for df_speaker Max Straubinger and real speaker ['Max Straubinger']
# Match found for df_speaker Jens Teutrine and real speaker ['Jens Teutrine']
# Match found for df_speaker Alexander Ulrich and real speaker ['Alexander Ulrich']
# Match found for df_speaker Tobias Winkler and real speaker ['Tobias Winkler']
# Match found for df_speaker Katharina Dröge and real speaker ['Katharina Dröge']
# Match found for df_speaker Christian Dürr and real speaker ['Christian Dürr']
# Match found for df_speaker Saskia Esken and real speaker ['Saskia Esken']
# Match found for df_speaker Lars Klingbeil and real speaker ['Lars Klingbeil']
# Match found for df_speaker Dagmar Schmidt and real speaker ['Dagmar Schmidt']
# Match found for df_speaker Dagmar Schmidt and real speaker ['Dagmar Schmidt']
# Match found for df_speaker Dennis Rohde and real speaker ['Dennis Rohde']
# Match found for df_speaker Carsten Körber and real speaker ['Carsten Körber']
# Match found for df_speaker Bettina Hagedorn and real speaker ['Bettina Hagedorn']
# Match found for df_speaker Helge Braun and real speaker ['Helge Braun']
# Match found for df_speaker Sebastian Schäfer and real speaker ['Sebastian Schäfer']
# Match found for df_speaker Michael Brand and real speaker ['Michael Brand']
# Match found for df_speaker Jürgen Braun and real speaker ['Jürgen Braun']
# Match found for df_speaker Max Lucks and real speaker ['Max Lucks']
# Match found for df_speaker Renata Alt and real speaker ['Renata Alt']
# Match found for df_speaker Markus Grübel and real speaker ['Markus Grübel']
# Match found for df_speaker Jonas Geissler and real speaker ['Jonas Geissler']
# Match found for df_speaker Andreas Mattfeldt and real speaker ['Andreas Mattfeldt']
# Match found for df_speaker Verena Hubertz and real speaker ['Verena Hubertz']
# Match found for df_speaker Michael Espendiller and real speaker ['Michael Espendiller']
# Match found for df_speaker Jamila Schäfer and real speaker ['Jamila Schäfer']
# Match found for df_speaker Kathrin Michel and real speaker ['Kathrin Michel']
# Match found for df_speaker Dorothee Bär and real speaker ['Dorothee Mantel', 'Dorothee Bär']
# Match found for df_speaker André Berghegger and real speaker ['André Berghegger']
# Match found for df_speaker Sanae Abdi and real speaker ['Sanae Abdi']
# Match found for df_speaker Jens Koeppen and real speaker ['Jens Koeppen']
# Match found for df_speaker Stefan Wenzel and real speaker ['Stefan Wenzel']
# Match found for df_speaker Jakob Blankenburg and real speaker ['Jakob Blankenburg']
# Match found for df_speaker Katja Kipping and real speaker ['Katja Kipping']
# Match found for df_speaker Annika Klose and real speaker ['Annika Klose']
# Match found for df_speaker Gerrit Huy and real speaker ['Gerrit Huy']
# Match found for df_speaker Takis Mehmet Ali and real speaker ['Takis Mehmet Ali']
# Match found for df_speaker Patrick Schnieder and real speaker ['Patrick Schnieder']
# Match found for df_speaker Irene Mihalic and real speaker ['Irene Mihalic']
# Match found for df_speaker Stephan Thomae and real speaker ['Stephan Thomae']
# Match found for df_speaker Michael Frieser and real speaker ['Michael Frieser']
# Match found for df_speaker Stefan Keuter and real speaker ['Stefan Keuter']
# Match found for df_speaker Johannes Vogel and real speaker ['Johannes Vogel', 'Johannes Vogel', 'Johannes Vogel']
# Match found for df_speaker Katja Mast and real speaker ['Katja Mast']
# Match found for df_speaker Dieter Janecek and real speaker ['Dieter Janecek']
# Match found for df_speaker Pascal Meiser and real speaker ['Pascal Meiser']
# Match found for df_speaker Manfred Todtenhausen and real speaker ['Manfred Todtenhausen']
# Match found for df_speaker Lena Werner and real speaker ['Lena Werner']
# Match found for df_speaker Klaus-Peter Willsch and real speaker ['Klaus-Peter Willsch']
# Match found for df_speaker Katharina Beck and real speaker ['Katharina Beck']
# Match found for df_speaker Kristine Lütke and real speaker ['Kristine Lütke']
# Match found for df_speaker Esra Limbacher and real speaker ['Esra Limbacher']
# Match found for df_speaker Katrin Uhlig and real speaker ['Katrin Uhlig']
# Match found for df_speaker Günter Krings and real speaker ['Günter Krings']
# Match found for df_speaker Wolfgang Strengmann-Kuhn and real speaker ['Wolfgang Strengmann-Kuhn']
# Match found for df_speaker Sepp Müller and real speaker ['Sepp Müller']
# Match found for df_speaker Ann-Veruschka Jurisch and real speaker ['Ann-Veruschka Jurisch']
# Match found for df_speaker Ralf Stegner and real speaker ['Ralf Stegner']
# Match found for df_speaker André Hahn and real speaker ['André Hahn']
# Match found for df_speaker Lamya Kaddor and real speaker ['Lamya Kaddor']
# Match found for df_speaker Konstantin Kuhle and real speaker ['Konstantin Kuhle']
# Match found for df_speaker Martina Renner and real speaker ['Martina Renner']
# Match found for df_speaker Alexander Throm and real speaker ['Alexander Throm']
# Match found for df_speaker Marcel Emmerich and real speaker ['Marcel Emmerich']
# Match found for df_speaker Manuel Höferlin and real speaker ['Manuel Höferlin']
# Match found for df_speaker Detlef Seif and real speaker ['Detlef Seif']
# Match found for df_speaker Stephan Mayer and real speaker ['Stephan Mayer']
# Match found for df_speaker Sebastian Hartmann and real speaker ['Sebastian Hartmann']
# Match found for df_speaker Thomas Seitz and real speaker ['Thomas Seitz']
# Match found for df_speaker Helge Limburg and real speaker ['Helge Limburg']
# Match found for df_speaker Sonja Eichwede and real speaker ['Sonja Eichwede']
# Match found for df_speaker Canan Bayram and real speaker ['Canan Bayram']
# Match found for df_speaker Macit Karaahmetoğlu and real speaker ['Macit Karaahmetoğlu']
# Match found for df_speaker Carmen Wegge and real speaker ['Carmen Wegge']
# Match found for df_speaker Petr Bystron and real speaker ['Petr Bystron']
# Match found for df_speaker Gregor Gysi and real speaker ['Gregor Gysi']
# Match found for df_speaker Patricia Lips and real speaker ['Patricia Lips']
# Match found for df_speaker Axel Schäfer and real speaker ['Axel Schäfer']
# Match found for df_speaker Bijan Djir-Sarai and real speaker ['Bijan Djir-Sarai']
# Match found for df_speaker Derya Türk-Nachbaur and real speaker ['Derya Türk-Nachbaur']
# Match found for df_speaker Steffen Bilger and real speaker ['Steffen Bilger']
# Match found for df_speaker Andreas Bleck and real speaker ['Andreas Bleck']
# Match found for df_speaker Björn Simon and real speaker ['Björn Simon']
# Match found for df_speaker Franziska Kersten and real speaker ['Franziska Kersten']
# Match found for df_speaker Muhanad Al-Halak and real speaker ['Muhanad Al-Halak']
# Match found for df_speaker Daniel Schneider and real speaker ['Daniel Schneider']
# Match found for df_speaker Julia Klöckner and real speaker ['Julia Klöckner']
# Match found for df_speaker Leif-Erik Holm and real speaker ['Leif-Erik Holm']
# Match found for df_speaker Klaus Ernst and real speaker ['Klaus Ernst']
# Match found for df_speaker Ingrid Nestle and real speaker ['Ingrid Nestle', 'Ingrid Nestle']
# Match found for df_speaker Matthias Miersch and real speaker ['Matthias Miersch']
# Match found for df_speaker Anja Karliczek and real speaker ['Anja Karliczek']
# Match found for df_speaker Hansjörg Durz and real speaker ['Hansjörg Durz']
# Match found for df_speaker Michael Kruse and real speaker ['Michael Kruse']
# Match found for df_speaker Nina Stahr and real speaker ['Nina Stahr']
# Match found for df_speaker Ria Schröder and real speaker ['Ria Schröder']
# Match found for df_speaker Thomas Jarzombek and real speaker ['Thomas Jarzombek']
# Match found for df_speaker Katrin Zschau and real speaker ['Katrin Zschau']
# Match found for df_speaker Anja Reinalter and real speaker ['Anja Reinalter']
# Match found for df_speaker Petra Sitte and real speaker ['Petra Sitte']
# Match found for df_speaker Maja Wallstein and real speaker ['Maja Wallstein']
# Match found for df_speaker Daniela Ludwig and real speaker ['Daniela Raab', 'Daniela Ludwig']
# Match found for df_speaker Laura Kraft and real speaker ['Laura Kraft']
# Match found for df_speaker Ye-One Rhie and real speaker ['Ye-One Rhie']
# Match found for df_speaker Kirsten Kappert-Gonther and real speaker ['Kirsten Kappert-Gonther']
# Match found for df_speaker Saskia Weishaupt and real speaker ['Saskia Weishaupt']
# Match found for df_speaker Armin Grau and real speaker ['Armin Grau']
# Match found for df_speaker Kerstin Griese and real speaker ['Kerstin Griese']
# Match found for df_speaker Hermann Gröhe and real speaker ['Hermann Gröhe']
# Match found for df_speaker Frank Bsirske and real speaker ['Frank Bsirske']
# Match found for df_speaker René Springer and real speaker ['René Springer']
# Match found for df_speaker Axel Knoerig and real speaker ['Axel Knoerig']
# Match found for df_speaker Stephanie Aeffner and real speaker ['Stephanie Aeffner']
# Match found for df_speaker Hannes Gnauck and real speaker ['Hannes Gnauck']
# Match found for df_speaker Jasmina Hostert and real speaker ['Jasmina Hostert']
# Match found for df_speaker Gyde Jensen and real speaker ['Gyde Jensen']
# Match found for df_speaker Heidi Reichinnek and real speaker ['Heidi Reichinnek']
# Match found for df_speaker Ulle Schauws and real speaker ['Ulle Schauws']
# Match found for df_speaker Daniel Baldy and real speaker ['Daniel Baldy']
# Match found for df_speaker Christoph De Vries and real speaker ['Christoph Vries']
# Match found for df_speaker Martin Gassner-Herz and real speaker ['Martin Gassner-Herz']
# Match found for df_speaker Anke Hennig and real speaker ['Anke Hennig']
# Match found for df_speaker Johannes Huber and real speaker ['Johannes Huber']
# Match found for df_speaker Felix Döring and real speaker ['Felix Döring']
# Match found for df_speaker Carsten Schneider and real speaker ['Carsten Schneider']
# Match found for df_speaker Filiz Polat and real speaker ['Filiz Polat']
# Match found for df_speaker Marc Jongen and real speaker ['Marc Jongen']
# Match found for df_speaker Hagen Reinhold and real speaker ['Hagen Reinhold']
# Match found for df_speaker Sören Pellmann and real speaker ['Sören Pellmann']
# Match found for df_speaker Reem Alabali-Radovan and real speaker ['Reem Alabali-Radovan']
# Match found for df_speaker Erhard Grundl and real speaker ['Erhard Grundl']
# Match found for df_speaker Martin Erwin Renner and real speaker ['Martin Erwin Renner']
# Match found for df_speaker Thomas Hacker and real speaker ['Thomas Hacker']
# Match found for df_speaker Christiane Schenderlein and real speaker ['Christiane Schenderlein']
# Match found for df_speaker Helge Lindh and real speaker ['Helge Lindh']
# Match found for df_speaker Thomas Bareiß and real speaker ['Thomas Bareiß']
# Match found for df_speaker Joana Cotar and real speaker ['Joana Cotar']
# Match found for df_speaker Maximilian Funke-Kaiser and real speaker ['Maximilian Funke-Kaiser']
# Match found for df_speaker Ulrich Lange and real speaker ['Ulrich Lange']
# Match found for df_speaker Jens Zimmermann and real speaker ['Jens Zimmermann']
# Match found for df_speaker Anke Domscheit-Berg and real speaker ['Anke Domscheit-Berg']
# Match found for df_speaker Dorothee Martin and real speaker ['Dorothee Martin']
# Match found for df_speaker Anna Kassautzki and real speaker ['Anna Kassautzki']
# Match found for df_speaker Reinhard Brandl and real speaker ['Reinhard Brandl']
# Match found for df_speaker Maik Außendorf and real speaker ['Maik Außendorf']
# Match found for df_speaker Isabel Cademartori Dujisin and real speaker ['Isabel Cademartori Dujisin']
# Match found for df_speaker Christina-Johanne Schröder and real speaker ['Christina-Johanne Schröder']
# Match found for df_speaker Roger Beckamp and real speaker ['Roger Beckamp']
# Match found for df_speaker Carina Konrad and real speaker ['Carina Konrad']
# Match found for df_speaker Caren Lay and real speaker ['Caren Lay']
# Match found for df_speaker Petra Nicolaisen and real speaker ['Petra Nicolaisen']
# Match found for df_speaker Kassem Taher Saleh and real speaker ['Kassem Taher Saleh', 'Kassem Taher Saleh']
# Match found for df_speaker Franziska Mascheck and real speaker ['Franziska Mascheck']
# Match found for df_speaker Karoline Otte and real speaker ['Karoline Otte']
# Match found for df_speaker Diana Stöcker and real speaker ['Diana Stöcker']
# Match found for df_speaker Robert Farle and real speaker ['Robert Farle']
# Match found for df_speaker Ates Gürpinar and real speaker ['Ates Gürpinar']
# Match found for df_speaker Michael Schrodi and real speaker ['Michael Schrodi']
# Match found for df_speaker Christoph Meyer and real speaker ['Christoph Meyer']
# Match found for df_speaker Dagmar Andres and real speaker ['Dagmar Andres']
# Match found for df_speaker Albrecht Glaser and real speaker ['Albrecht Glaser']
# Match found for df_speaker Wiebke Papenbrock and real speaker ['Wiebke Papenbrock']
# Match found for df_speaker Thorsten Rudolph and real speaker ['Thorsten Rudolph']
# Match found for df_speaker Stephan Protschka and real speaker ['Stephan Protschka']
# Match found for df_speaker Gero Clemens Hocker and real speaker ['Gero Clemens Hocker']
# Match found for df_speaker Ina Latendorf and real speaker ['Ina Latendorf']
# Match found for df_speaker Zoe Mayer and real speaker ['Zoe Mayer']
# Match found for df_speaker Albert Stegemann and real speaker ['Albert Stegemann']
# Match found for df_speaker Frank Rinck and real speaker ['Frank Rinck']
# Match found for df_speaker Karlheinz Busen and real speaker ['Karlheinz Busen']
# Match found for df_speaker Isabel Mackensen-Geis and real speaker ['Isabel Mackensen', 'Isabel Mackensen-Geis']
# Match found for df_speaker Peggy Schierenbeck and real speaker ['Peggy Schierenbeck']
# Match found for df_speaker Florian Hahn and real speaker ['Florian Hahn']
# Match found for df_speaker Agnieszka Brugger and real speaker ['Agnes Malczak', 'Agnieszka Brugger']
# Match found for df_speaker Rüdiger Lucassen and real speaker ['Rüdiger Lucassen']
# Match found for df_speaker Marcus Faber and real speaker ['Marcus Faber']
# Match found for df_speaker Kerstin Vieregge and real speaker ['Kerstin Vieregge']
# Match found for df_speaker Sara Nanni and real speaker ['Sara Nanni']
# Match found for df_speaker Marie-Agnes Strack-Zimmermann and real speaker ['Marie-Agnes Strack-Zimmermann']
# Match found for df_speaker Kevin Leiser and real speaker ['Kevin Leiser']
# Match found for df_speaker Jens Lehmann and real speaker ['Jens Lehmann']
# Match found for df_speaker Deborah Düring and real speaker ['Deborah Düring']
# Match found for df_speaker Cornelia Möhring and real speaker ['Cornelia Möhring']
# Match found for df_speaker Wolfgang Stefinger and real speaker ['Wolfgang Stefinger']
# Match found for df_speaker Jan-Niclas Gesenhues and real speaker ['Jan-Niclas Gesenhues']
# Match found for df_speaker Dietmar Friedhoff and real speaker ['Dietmar Friedhoff']
# Match found for df_speaker Christoph Hoffmann and real speaker ['Christoph Hoffmann']
# Match found for df_speaker Nadja Sthamer and real speaker ['Nadja Sthamer']
# Match found for df_speaker Volkmar Klein and real speaker ['Volkmar Klein']
# Match found for df_speaker Kathrin Henneberger and real speaker ['Kathrin Henneberger']
# Match found for df_speaker Joachim Wundrak and real speaker ['Joachim Wundrak']
# Match found for df_speaker Sevim Dağdelen and real speaker ['Sevim Dağdelen']
# Match found for df_speaker Malte Kaufmann and real speaker ['Malte Kaufmann']
# Match found for df_speaker Falko Mohrs and real speaker ['Falko Mohrs']
# Match found for df_speaker Hannes Walter and real speaker ['Hannes Walter']
# Match found for df_speaker Johannes Arlt and real speaker ['Johannes Arlt']
# Match found for df_speaker Gitta Connemann and real speaker ['Gitta Connemann']
# Match found for df_speaker Thomas Gebhart and real speaker ['Thomas Gebhart']
# Match found for df_speaker Stefan Rouenhoff and real speaker ['Stefan Rouenhoff']
# Match found for df_speaker Paula Piechotta and real speaker ['Paula Piechotta']
# Match found for df_speaker Till Steffen and real speaker ['Till Steffen']
# Match found for df_speaker Rasha Nasr and real speaker ['Rasha Nasr']
# Match found for df_speaker Ricarda Lang and real speaker ['Ricarda Lang']
# Match found for df_speaker Kordula Schulz-Asche and real speaker ['Kordula Schulz-Asche']
# Match found for df_speaker Gereon Bollmann and real speaker ['Gereon Bollmann']
# Match found for df_speaker Christos Pantazis and real speaker ['Christos Pantazis']
# Match found for df_speaker Georg Kippels and real speaker ['Georg Kippels']
# Match found for df_speaker Heike Brehmer and real speaker ['Heike Brehmer']
# Match found for df_speaker Ingeborg Gräßle and real speaker ['Ingeborg Gräßle']
# Match found for df_speaker Holger Mann and real speaker ['Holger Mann']
# Match found for df_speaker Claudia Raffelhüschen and real speaker ['Claudia Raffelhüschen']
# Match found for df_speaker Tabea Rößner and real speaker ['Tabea Rößner']
# Match found for df_speaker Stefan Schmidt and real speaker ['Stefan Schmidt']
# Match found for df_speaker Carolin Wagner and real speaker ['Carolin Wagner']
# Match found for df_speaker Johannes Wagner and real speaker ['Johannes Wagner']
# Match found for df_speaker Friedrich Merz and real speaker ['Friedrich Merz']
# Match found for df_speaker Roderich Kiesewetter and real speaker ['Roderich Kiesewetter']
# Match found for df_speaker Michael Roth and real speaker ['Michael Roth']
# Match found for df_speaker Johannes Schraps and real speaker ['Johannes Schraps']
# Match found for df_speaker Joe Weingarten and real speaker ['Joe Weingarten']
# Match found for df_speaker Anna Lührmann and real speaker ['Anna Lührmann']
# Match found for df_speaker Gunther Krichbaum and real speaker ['Gunther Krichbaum']
# Match found for df_speaker Anton Hofreiter and real speaker ['Anton Hofreiter']
# Match found for df_speaker Ottilie Klein and real speaker ['Ottilie Klein']
# Match found for df_speaker Fabian Funke and real speaker ['Fabian Funke']
# Match found for df_speaker Harald Weyel and real speaker ['Harald Weyel']
# Match found for df_speaker Alexander Radwan and real speaker ['Alexander Radwan']
# Match found for df_speaker Andreas Larem and real speaker ['Andreas Larem']
# Match found for df_speaker Anikó Merten and real speaker ['Anikó Merten', 'Anikó Glogowski-Merten']
# Match found for df_speaker Markus Töns and real speaker ['Markus Töns']
# Match found for df_speaker Wolfgang Wiehle and real speaker ['Wolfgang Wiehle']
# Match found for df_speaker Janine Wissler and real speaker ['Janine Wissler']
# Match found for df_speaker Felix Banaszak and real speaker ['Felix Banaszak']
# Match found for df_speaker Frank Junge and real speaker ['Frank Junge']
# Match found for df_speaker Renate Künast and real speaker ['Renate Künast']
# Match found for df_speaker Hermann Färber and real speaker ['Hermann Färber']
# Match found for df_speaker Luiza Licina-Bode and real speaker ['Luiza Licina-Bode']
# Match found for df_speaker Johannes Schätzl and real speaker ['Johannes Schätzl']
# Match found for df_speaker Oliver Vogt and real speaker ['Oliver Vogt']
# Match found for df_speaker Matthias David Mieves and real speaker ['Matthias David Mieves']
# Match found for df_speaker Tina Rudolph and real speaker ['Tina Rudolph']
# Match found for df_speaker Knut Abraham and real speaker ['Knut Abraham']
# Match found for df_speaker Rainer Johannes Keller and real speaker ['Rainer Johannes Keller']
# Match found for df_speaker Enrico Komning and real speaker ['Enrico Komning']
# Match found for df_speaker Christian Leye and real speaker ['Christian Leye']
# Match found for df_speaker Sebastian Roloff and real speaker ['Sebastian Roloff']
# Match found for df_speaker Bernhard Loos and real speaker ['Bernhard Loos']
# Match found for df_speaker Sandra Detzer and real speaker ['Sandra Detzer']
# Match found for df_speaker Bernd Schattner and real speaker ['Bernd Schattner']
# Match found for df_speaker Anne Monika Spallek and real speaker ['Anne Monika Spallek']
# Match found for df_speaker Ingo Bodtke and real speaker ['Ingo Bodtke']
# Match found for df_speaker Christina Stumpp and real speaker ['Christina Stumpp']
# Match found for df_speaker Natalie Pawlik and real speaker ['Natalie Pawlik']
# Match found for df_speaker Norbert Röttgen and real speaker ['Norbert Röttgen']
# Match found for df_speaker Michael Müller and real speaker ['Michael Müller']
# Match found for df_speaker Michael Müller and real speaker ['Michael Müller']
# Match found for df_speaker Gerold Otten and real speaker ['Gerold Otten']
# Match found for df_speaker Ulrich Lechte and real speaker ['Ulrich Lechte']
# Match found for df_speaker Kristian Klinck and real speaker ['Kristian Klinck']
# Match found for df_speaker Philipp Amthor and real speaker ['Philipp Amthor']
# Match found for df_speaker Leon Eckert and real speaker ['Leon Eckert']
# Match found for df_speaker Alexander Hoffmann and real speaker ['Alexander Hoffmann']
# Match found for df_speaker Claudia Tausend and real speaker ['Claudia Tausend']
# Match found for df_speaker Lars Rohwer and real speaker ['Lars Rohwer']
# Match found for df_speaker Carolin Bachmann and real speaker ['Carolin Bachmann']
# Match found for df_speaker Rainer Semet and real speaker ['Rainer Semet']
# Match found for df_speaker Emmi Zeulner and real speaker ['Emmi Zeulner']
# Match found for df_speaker Hanna Steinmüller and real speaker ['Hanna Steinmüller']
# Match found for df_speaker Parsa Marvi and real speaker ['Parsa Marvi']
# Match found for df_speaker Christian Wirth and real speaker ['Christian Wirth']
# Match found for df_speaker Benjamin Strasser and real speaker ['Benjamin Strasser']
# Match found for df_speaker Hakan Demir and real speaker ['Hakan Demir']
# Match found for df_speaker Michael Breilmann and real speaker ['Michael Breilmann']
# Match found for df_speaker Schahina Gambir and real speaker ['Schahina Gambir']
# Match found for df_speaker Lennard Oehl and real speaker ['Lennard Oehl']
# Match found for df_speaker Stefan Heck and real speaker ['Stefan Heck']
# Match found for df_speaker Uli Grötsch and real speaker ['Uli Grötsch']
# Match found for df_speaker Knut Gerschau and real speaker ['Knut Gerschau']
# Match found for df_speaker Rebecca Schamber and real speaker ['Rebecca Schamber']
# Match found for df_speaker Edgar Naujok and real speaker ['Edgar Naujok']
# Match found for df_speaker Manuel Gava and real speaker ['Manuel Gava']
# Match found for df_speaker Nicolas Zippelius and real speaker ['Nicolas Zippelius']
# Match found for df_speaker Karamba Diaby and real speaker ['Karamba Diaby']
# Match found for df_speaker Eugen Schmidt and real speaker ['Eugen Schmidt']
# Match found for df_speaker Adis Ahmetovic and real speaker ['Adis Ahmetovic']
# Match found for df_speaker Mareike Lotte Wulf and real speaker ['Mareike Lotte Wulf']
# Match found for df_speaker Ariane Fäscher and real speaker ['Ariane Fäscher']
# Match found for df_speaker Mariana Iris Harder-Kühnel and real speaker ['Mariana Iris Harder-Kühnel']
# Match found for df_speaker Nicole Bauer and real speaker ['Nicole Bauer']
# Match found for df_speaker Mechthild Heil and real speaker ['Mechthild Heil']
# Match found for df_speaker Erik Von Malottki and real speaker ['Erik Malottki']
# Match found for df_speaker Beatrix Von Storch and real speaker ['Beatrix Storch']
# Match found for df_speaker Sarah Lahrkamp and real speaker ['Sarah Lahrkamp']
# Match found for df_speaker Leni Breymaier and real speaker ['Leni Breymaier']
# Match found for df_speaker Tessa Ganserer and real speaker ['Tessa Ganserer']
# Match found for df_speaker Ulrike Harzer and real speaker ['Ulrike Harzer']
# Match found for df_speaker Helmut Kleebank and real speaker ['Helmut Kleebank']
# Match found for df_speaker Alexander Engelhard and real speaker ['Alexander Engelhard']
# Match found for df_speaker Olav Gutting and real speaker ['Olav Gutting']
# Match found for df_speaker Sascha Müller and real speaker ['Sascha Müller']
# Match found for df_speaker Maximilian Mordhorst and real speaker ['Maximilian Mordhorst']
# Match found for df_speaker Norbert Maria Altenkamp and real speaker ['Norbert Maria Altenkamp']
# Match found for df_speaker Jan Metzler and real speaker ['Jan Metzler']
# Match found for df_speaker Gerald Ullrich and real speaker ['Gerald Ullrich']
# Match found for df_speaker Michael Kellner and real speaker ['Michael Kellner']
# Match found for df_speaker Axel Müller and real speaker ['Axel Müller']
# Match found for df_speaker Clara Bünger and real speaker ['Clara Bünger']
# Match found for df_speaker Josef Oster and real speaker ['Josef Oster']
# Match found for df_speaker Gülistan Yüksel and real speaker ['Gülistan Yüksel']
# Match found for df_speaker Siemtje Möller and real speaker ['Siemtje Möller']
# Match found for df_speaker Annette Widmann-Mauz and real speaker ['Annette Widmann-Mauz']
# Match found for df_speaker Jens Beeck and real speaker ['Jens Beeck']
# Match found for df_speaker Jürgen Coße and real speaker ['Jürgen Coße']
# Match found for df_speaker Markus Koob and real speaker ['Markus Koob']
# Match found for df_speaker Thomas Röwekamp and real speaker ['Thomas Röwekamp']
# Match found for df_speaker Heike Engelhardt and real speaker ['Heike Engelhardt']
# Match found for df_speaker Nicole Westig and real speaker ['Nicole Westig']
# Match found for df_speaker Nezahat Baradari and real speaker ['Nezahat Baradari']
# Match found for df_speaker Enak Ferlemann and real speaker ['Enak Ferlemann']
# Match found for df_speaker Brian Nickholz and real speaker ['Brian Nickholz']
# Match found for df_speaker Thomas Dietz and real speaker ['Thomas Dietz']
# Match found for df_speaker Linda Heitmann and real speaker ['Linda Heitmann']
# Match found for df_speaker Gero Storjohann and real speaker ['Gero Storjohann']
# Match found for df_speaker Sandra Bubendorfer-Licht and real speaker ['Sandra Bubendorfer-Licht']
# Match found for df_speaker Konstantin Von Notz and real speaker ['Konstantin Notz']
# Match found for df_speaker Philipp Hartewig and real speaker ['Philipp Hartewig']
# Match found for df_speaker Jörg Nürnberger and real speaker ['Jörg Nürnberger']
# Match found for df_speaker Konrad Stockmeier and real speaker ['Konrad Stockmeier']
# Match found for df_speaker Chantal Kopf and real speaker ['Chantal Kopf']
# Match found for df_speaker Catarina Dos Santos Firnhaber and real speaker ['Catarina Santos Firnhaber', 'Catarina Santos-Wintz']
# Match found for df_speaker Andreas Mehltretter and real speaker ['Andreas Mehltretter']
# Match found for df_speaker Bernhard Herrmann and real speaker ['Bernhard Herrmann']
# Match found for df_speaker Carlos Kasper and real speaker ['Carlos Kasper']
# Match found for df_speaker Tina Winklmann and real speaker ['Tina Winklmann']
# Match found for df_speaker Jens Peick and real speaker ['Jens Peick']
# Match found for df_speaker Susanne Hennig-Wellsow and real speaker ['Susanne Hennig-Wellsow']
# Match found for df_speaker Martin Diedenhofen and real speaker ['Martin Diedenhofen']
# Match found for df_speaker Anja Liebert and real speaker ['Anja Liebert']
# Match found for df_speaker Timo Schisanowski and real speaker ['Timo Schisanowski']
# Match found for df_speaker Michael Kießling and real speaker ['Michael Kießling']
# Match found for df_speaker Marc Henrichmann and real speaker ['Marc Henrichmann']
# Match found for df_speaker Thomas Heilmann and real speaker ['Thomas Heilmann']
# Match found for df_speaker Merle Spellerberg and real speaker ['Merle Spellerberg']
# Match found for df_speaker Christoph Schmid and real speaker ['Christoph Schmid']
# Match found for df_speaker Armin Schwarz and real speaker ['Armin Schwarz']
# No match found for df_speaker Dietmar Woidke and real speaker ['Christian Bartelt']
# Match found for df_speaker Gabriela Heinrich and real speaker ['Gabriela Heinrich']
# Match found for df_speaker Mario Czaja and real speaker ['Mario Czaja']
# Match found for df_speaker Misbah Khan and real speaker ['Misbah Khan']
# Match found for df_speaker Philip Krämer and real speaker ['Philip Krämer']
# Match found for df_speaker Matthias Moosdorf and real speaker ['Matthias Moosdorf']
# Match found for df_speaker Dunja Kreiser and real speaker ['Dunja Kreiser']
# Match found for df_speaker Torsten Herbst and real speaker ['Torsten Herbst']
# Match found for df_speaker Ingo Schäfer and real speaker ['Ingo Schäfer']
# Match found for df_speaker Ansgar Heveling and real speaker ['Ansgar Heveling']
# No match found for df_speaker Andreas Bovenschulte and real speaker ['Christian Bartelt']
# Match found for df_speaker Herbert Wollmann and real speaker ['Herbert Wollmann']
# Match found for df_speaker Emilia Fester and real speaker ['Emilia Fester']
# Match found for df_speaker Kaweh Mansoori and real speaker ['Kaweh Mansoori']
# Match found for df_speaker Olaf In Der Beek and real speaker ['Olaf In der Beek']
# Match found for df_speaker Robin Mesarosch and real speaker ['Robin Mesarosch']
# Match found for df_speaker Lisa Badum and real speaker ['Lisa Badum']
# Match found for df_speaker Katrin Budde and real speaker ['Katrin Budde']
# Match found for df_speaker Nico Tippelt and real speaker ['Nico Tippelt']
# Match found for df_speaker Simona Koß and real speaker ['Simona Koß']
# Match found for df_speaker Manfred Grund and real speaker ['Manfred Grund']
# Match found for df_speaker Zanda Martens and real speaker ['Zanda Martens']
# Match found for df_speaker Tobias Matthias Peterka and real speaker ['Tobias Matthias Peterka']
# Match found for df_speaker Sebastian Fiedler and real speaker ['Sebastian Fiedler']
# Match found for df_speaker Anne König and real speaker ['Anne König']
# Match found for df_speaker Sandra Weeser and real speaker ['Sandra Weeser']
# Match found for df_speaker Lina Seitzl and real speaker ['Lina Seitzl']
# Match found for df_speaker Corinna Rüffer and real speaker ['Corinna Rüffer']
# Match found for df_speaker Hubert Hüppe and real speaker ['Hubert Hüppe']
# Match found for df_speaker Angelika Glöckner and real speaker ['Angelika Glöckner']
# Match found for df_speaker Awet Tesfaiesus and real speaker ['Awet Tesfaiesus']
# Match found for df_speaker Maximilian Mörseburg and real speaker ['Maximilian Mörseburg']
# Match found for df_speaker Bernd Baumann and real speaker ['Bernd Baumann']
# Match found for df_speaker Ralph Edelhäußer and real speaker ['Ralph Edelhäußer']
# Match found for df_speaker Maria-Lena Weiss and real speaker ['Maria-Lena Weiss']
# Match found for df_speaker Rita Hagl-Kehl and real speaker ['Rita Hagl-Kehl']
# Match found for df_speaker Karl Bär and real speaker ['Karl Bär']
# Match found for df_speaker Bengt Bergt and real speaker ['Bengt Bergt']
# Match found for df_speaker Nadine Heselhaus and real speaker ['Nadine Heselhaus']
# Match found for df_speaker Tim Klüssendorf and real speaker ['Tim Klüssendorf']
# Match found for df_speaker Sahra Wagenknecht and real speaker ['Sahra Wagenknecht']
# Match found for df_speaker Sylvia Lehmann and real speaker ['Sylvia Lehmann']
# Match found for df_speaker Metin Hakverdi and real speaker ['Metin Hakverdi']
# Match found for df_speaker Mathias Papendieck and real speaker ['Mathias Papendieck']
# Match found for df_speaker Jürgen Berghahn and real speaker ['Jürgen Berghahn']
# Match found for df_speaker Nyke Slawik and real speaker ['Nyke Slawik']
# ...
# Match found for df_speaker Ralf Kapschack and real speaker ['Ralf Kapschack']
# Match found for df_speaker Ursula Schulte and real speaker ['Ursula Schulte']
# Match found for df_speaker Sybille Benning and real speaker ['Sybille Benning']
# Match found for df_speaker Alexandra Dinges-Dierig and real speaker ['Alexandra Dinges-Dierig']
# Match found for df_speaker Xaver Jung and real speaker ['Xaver Jung']
# Match found for df_speaker Rainer Spiering and real speaker ['Rainer Spiering']
# Match found for df_speaker Wilfried Lorenz and real speaker ['Wilfried Lorenz']
# Match found for df_speaker Matthias Bartke and real speaker ['Matthias Bartke']
# Match found for df_speaker Heiko Schmelzle and real speaker ['Heiko Schmelzle']
# Match found for df_speaker Barbara Woltmann and real speaker ['Barbara Woltmann']
# Match found for df_speaker Sebastian Steineke and real speaker ['Sebastian Steineke']
# Match found for df_speaker Christina Jantz and real speaker ['Christina Jantz', 'Christina Jantz-Herrmann']
# Match found for df_speaker Sylvia Pantel and real speaker ['Sylvia Pantel']
# Match found for df_speaker Burkhard Blienert and real speaker ['Burkhard Blienert']
# Match found for df_speaker Arno Klare and real speaker ['Arno Klare']
# Match found for df_speaker Claudia Lücking-Michel and real speaker ['Claudia Lücking-Michel']
# Match found for df_speaker Thomas Stritzl and real speaker ['Thomas Stritzl']
# Match found for df_speaker Maik Beermann and real speaker ['Maik Beermann']
# Match found for df_speaker Dorothee Schlegel and real speaker ['Dorothee Schlegel']
# No match found for df_speaker Aydan Özoguz and real speaker ['Christian Bartelt']
# Match found for df_speaker Sven Volmering and real speaker ['Sven Volmering']
# Match found for df_speaker Helmut Nowak and real speaker ['Helmut Nowak']
# Match found for df_speaker Hans-Joachim Schabedoth and real speaker ['Hans-Joachim Schabedoth']
# Match found for df_speaker Christina Schwarzer and real speaker ['Christina Schwarzer']
# Match found for df_speaker Ingrid Pahlmann and real speaker ['Ingrid Pahlmann']
# Match found for df_speaker Marcus Held and real speaker ['Marcus Held']
# Match found for df_speaker Birgit Malecha-Nissen and real speaker ['Birgit Malecha-Nissen']
# Match found for df_speaker Oliver Wittke and real speaker ['Oliver Wittke']
# Match found for df_speaker Stefan Zierke and real speaker ['Stefan Zierke']
# Match found for df_speaker Kordula Kovac and real speaker ['Kordula Kovac']
# Match found for df_speaker Susann Rüthrich and real speaker ['Susann Rüthrich']
# Match found for df_speaker Jörg Hellmuth and real speaker ['Jörg Hellmuth']
# Match found for df_speaker Ulrich Hampel and real speaker ['Ulrich Hampel']
# Match found for df_speaker Karsten Möring and real speaker ['Karsten Möring']
# No match found for df_speaker Klaus-Dieter Fritsche and real speaker ['Christian Bartelt']
# Match found for df_speaker Waldemar Westermayer and real speaker ['Waldemar Westermayer']
# No match found for df_speaker Jutta Blankau-Rosenfeldt and real speaker ['Christian Bartelt']
# Match found for df_speaker Norbert Müller and real speaker ['Norbert Müller']
# No match found for df_speaker Heike Werner and real speaker ['Christian Bartelt']
# No match found for df_speaker Olaf Lies and real speaker ['Christian Bartelt']
# Match found for df_speaker Ronja Schmitt and real speaker ['Ronja Schmitt', 'Ronja Kemmer']
# Match found for df_speaker Thorsten Hoffmann and real speaker ['Thorsten Hoffmann']
# Match found for df_speaker Birgit Menz and real speaker ['Birgit Menz']
# Match found for df_speaker Iris Eberl and real speaker ['Iris Eberl']
# Match found for df_speaker Karin Thissen and real speaker ['Karin Thissen']
# Match found for df_speaker Elfi Scho-Antwerpes and real speaker ['Elfi Scho-Antwerpes']
# Match found for df_speaker Volker Mosblech and real speaker ['Volker Mosblech']
# Match found for df_speaker Petra Rode-Bosse and real speaker ['Petra Rode-Bosse']
# No match found for df_speaker Reinhold Gall and real speaker ['Christian Bartelt']
# No match found for df_speaker Verena Bentele and real speaker ['Christian Bartelt']
# No match found for df_speaker Monika Heinold and real speaker ['Christian Bartelt']
# Match found for df_speaker Kathrin Rösel and real speaker ['Kathrin Rösel']
# Match found for df_speaker Iris Ripsam and real speaker ['Iris Ripsam']
# Match found for df_speaker Bettina Bähr-Losse and real speaker ['Bettina Bähr-Losse']
# Match found for df_speaker Karl-Heinz Wange and real speaker ['Karl-Heinz Wange']
# No match found for df_speaker Christian Pegel and real speaker ['Christian Bartelt']
# Match found for df_speaker Rainer Hajek and real speaker ['Rainer Hajek']
# Match found for df_speaker Dirk Wiese and real speaker ['Dirk Wiese']
# No match found for df_speaker Malu Dreyer and real speaker ['Christian Bartelt']
# Match found for df_speaker Joachim Gauck and real speaker ['Joachim Gauck']
# No match found for df_speaker Winfried Kretschmann and real speaker ['Christian Bartelt']
# Match found for df_speaker Mathias Edwin Höschel and real speaker ['Mathias Edwin Höschel']
# No match found for df_speaker Volker Bouffier and real speaker ['Christian Bartelt']
# Match found for df_speaker Tobias Pflüger and real speaker ['Tobias Pflüger']
# Match found for df_speaker Martin Schulz and real speaker ['Martin Schulz']
# Match found for df_speaker Heiko Heßenkemper and real speaker ['Heiko Heßenkemper']
# Match found for df_speaker Fabio De Masi and real speaker ['Fabio De Masi']
# Match found for df_speaker Axel Gehrke and real speaker ['Axel Gehrke']
# Match found for df_speaker Lorenz Gösta Beutin and real speaker ['Lorenz Gösta Beutin']
# Match found for df_speaker Ulrich Oehme and real speaker ['Ulrich Oehme']
# Match found for df_speaker Armin-Paulus Hampel and real speaker ['Armin-Paulus Hampel']
# Match found for df_speaker Jens Maier and real speaker ['Jens Maier']
# Match found for df_speaker Birke Bull-Bischoff and real speaker ['Birke Bull-Bischoff']
# Match found for df_speaker Katja Suding and real speaker ['Katja Suding']
# Match found for df_speaker Albert H. Weiler and real speaker ['Albert Weiler', 'Albert Weiler', 'Albert H. Weiler', 'Albert H. Weiler']
# Match found for df_speaker Birgit Malsack-Winkemann and real speaker ['Birgit Malsack-Winkemann']
# Match found for df_speaker Matthias Höhn and real speaker ['Matthias Höhn']
# Match found for df_speaker Anton Friesen and real speaker ['Anton Friesen']
# Match found for df_speaker Jens Kestner and real speaker ['Jens Kestner']
# Match found for df_speaker Martin Hebner and real speaker ['Martin Hebner']
# Match found for df_speaker Nicola Beer and real speaker ['Nicola Beer']
# Match found for df_speaker Frauke Petry and real speaker ['Frauke Petry']
# Match found for df_speaker Frank Sitta and real speaker ['Frank Sitta']
# Match found for df_speaker Lars Herrmann and real speaker ['Lars Herrmann']
# Match found for df_speaker Friedrich Straetmanns and real speaker ['Friedrich Straetmanns']
# Match found for df_speaker Uwe Kamann and real speaker ['Uwe Kamann']
# Match found for df_speaker Eva-Maria Schreiber and real speaker ['Eva-Maria Schreiber']
# Match found for df_speaker Sonja Amalie Steffen and real speaker ['Sonja Steffen', 'Sonja Amalie Steffen']
# Match found for df_speaker Roman Johannes Reusch and real speaker ['Roman Johannes Reusch']
# Match found for df_speaker Grigorios Aggelidis and real speaker ['Grigorios Aggelidis']
# Match found for df_speaker Simone Barrientos and real speaker ['Simone Barrientos']
# Match found for df_speaker Ottmar Von Holtz and real speaker ['Ottmar Holtz']
# Match found for df_speaker Margit Stumpp and real speaker ['Margit Stumpp']
# Match found for df_speaker Franziska Gminder and real speaker ['Franziska Gminder']
# Match found for df_speaker Matern Von Marschall and real speaker ['Matern Marschall von Bieberstein', 'Matern Marschall']
# Match found for df_speaker Robby Schlund and real speaker ['Robby Schlund']
# No match found for df_speaker François De Rugy and real speaker ['Christian Bartelt']
# Match found for df_speaker Margarete Bause and real speaker ['Margarete Bause']
# Match found for df_speaker Michel Brandt and real speaker ['Michel Brandt']
# Match found for df_speaker Hansjörg Müller and real speaker ['Hansjörg Müller']
# Match found for df_speaker Wieland Schinnenburg and real speaker ['Wieland Schinnenburg']
# Match found for df_speaker Uwe Witt and real speaker ['Uwe Witt']
# Match found for df_speaker Mario Mieruch and real speaker ['Mario Mieruch']
# Match found for df_speaker Michael Kuffer and real speaker ['Michael Kuffer']
# Match found for df_speaker Elvan Korkmaz and real speaker ['Elvan Korkmaz', 'Elvan Korkmaz-Emre']
# Match found for df_speaker Jürgen Martens and real speaker ['Jürgen Martens']
# Match found for df_speaker Brigitte Freihold and real speaker ['Brigitte Freihold']
# Match found for df_speaker Detlev Spangenberg and real speaker ['Detlev Spangenberg']
# Match found for df_speaker Wilhelm Von Gottberg and real speaker ['Wilhelm Gottberg']
# Match found for df_speaker Michael Von Abercron and real speaker ['Michael Abercron']
# Match found for df_speaker Gabriele Lösekrug-Möller and real speaker ['Gabriele Lösekrug-Möller']
# Match found for df_speaker Roland Hartwig and real speaker ['Roland Hartwig']
# Match found for df_speaker Thomas L. Kemmerich and real speaker ['Thomas L. Kemmerich']
# Match found for df_speaker Danyal Bayaz and real speaker ['Danyal Bayaz']
# Match found for df_speaker Frank Magnitz and real speaker ['Frank Magnitz']
# Match found for df_speaker Alexander Krauß and real speaker ['Alexander Krauß']
# Match found for df_speaker Katharina Kloke and real speaker ['Katharina Kloke', 'Katharina Willkomm']
# Match found for df_speaker Volker Münz and real speaker ['Volker Münz']
# Match found for df_speaker Torbjörn Kartes and real speaker ['Torbjörn Kartes']
# Match found for df_speaker Roman Müller-Böhm and real speaker ['Roman Müller-Böhm']
# Match found for df_speaker Siegbert Droese and real speaker ['Siegbert Droese']
# Match found for df_speaker Nikolas Löbel and real speaker ['Nikolas Löbel']
# Match found for df_speaker Christoph Bernstiel and real speaker ['Christoph Bernstiel']
# Match found for df_speaker Hans-Jürgen Irmer and real speaker ['Hans-Jürgen Irmer']
# Match found for df_speaker Thomas Sattelberger and real speaker ['Thomas Sattelberger']
# Match found for df_speaker Doris Achelwilm and real speaker ['Doris Achelwilm']
# Match found for df_speaker Christian Jung and real speaker ['Christian Jung']
# Match found for df_speaker Andreas Wagner and real speaker ['Andreas Wagner']
# Match found for df_speaker Matthias Büttner and real speaker ['Matthias Büttner']
# Match found for df_speaker Manja Schüle and real speaker ['Manja Schüle']
# Match found for df_speaker Bettina Margarethe Wiesmann and real speaker ['Bettina Margarethe Wiesmann']
# No match found for df_speaker Franziska Giffey and real speaker ['Christian Bartelt']
# Match found for df_speaker Heiko Wildberg and real speaker ['Heiko Wildberg']
# Match found for df_speaker Alexander Kulitz and real speaker ['Alexander Kulitz']
# Match found for df_speaker Lothar Maier and real speaker ['Lothar Maier']
# Match found for df_speaker Helin Evrim Sommer and real speaker ['Helin Evrim Sommer']
# Match found for df_speaker Dietlind Tiemann and real speaker ['Dietlind Tiemann']
# Match found for df_speaker Udo Theodor Hemmelgarn and real speaker ['Udo Theodor Hemmelgarn']
# Match found for df_speaker Torsten Schweiger and real speaker ['Torsten Schweiger']
# Match found for df_speaker Jörg Cezanne and real speaker ['Jörg Cezanne']
# Match found for df_speaker Bruno Hollnagel and real speaker ['Bruno Hollnagel']
# Match found for df_speaker Astrid Mannes and real speaker ['Astrid Mannes']
# Match found for df_speaker Achim Kessler and real speaker ['Achim Kessler']
# Match found for df_speaker Verena Hartmann and real speaker ['Verena Hartmann']
# Match found for df_speaker Ulla Ihnen and real speaker ['Ulla Ihnen']
# Match found for df_speaker Stefan Sauer and real speaker ['Stefan Sauer']
# No match found for df_speaker Johannes Geismann and real speaker ['Christian Bartelt']
# Match found for df_speaker Britta Katharina Dassler and real speaker ['Britta Katharina Dassler']
# Match found for df_speaker Eckhard Gnodtke and real speaker ['Eckhard Gnodtke']
# Match found for df_speaker Andreas Steier and real speaker ['Andreas Steier']
# No match found for df_speaker Andreas Geisel and real speaker ['Christian Bartelt']
# Match found for df_speaker Andreas Mrosek and real speaker ['Andreas Mrosek']
# Match found for df_speaker Marcel Klinge and real speaker ['Marcel Klinge']
# Match found for df_speaker Claudia Schmidtke and real speaker ['Claudia Schmidtke']
# No match found for df_speaker Martin Dulig and real speaker ['Christian Bartelt']
# Match found for df_speaker Waldemar Herdt and real speaker ['Waldemar Herdt']
# Match found for df_speaker Hartmut Ebbing and real speaker ['Hartmut Ebbing']
# Match found for df_speaker Paul Viktor Podolay and real speaker ['Paul Viktor Podolay']
# Match found for df_speaker Berengar Elsner Von Gronow and real speaker ['Berengar Elsner von Gronow']
# Match found for df_speaker Frank Pasemann and real speaker ['Frank Pasemann']
# Match found for df_speaker Corinna Miazga and real speaker ['Corinna Miazga']
# Match found for df_speaker Sylvia Gabelmann and real speaker ['Sylvia Gabelmann']
# No match found for df_speaker Jürgen Dusel and real speaker ['Christian Bartelt']
# Match found for df_speaker Gerhard Zickenheiner and real speaker ['Gerhard Zickenheiner']
# Match found for df_speaker Isabel Mackensen and real speaker ['Isabel Mackensen', 'Isabel Mackensen-Geis']
# Match found for df_speaker Sarah Ryglewski and real speaker ['Sarah Ryglewski']
# Match found for df_speaker Michael Kretschmer and real speaker ['Michael Kretschmer']
# Match found for df_speaker Christoph Neumann and real speaker ['Christoph Neumann']
# No match found for df_speaker Elke Breitenbach and real speaker ['Christian Bartelt']
# No match found for df_speaker Benjamin-Immanuel Hoff and real speaker ['Christian Bartelt']
# No match found for df_speaker Boris Pistorius and real speaker ['Christian Bartelt']
# Match found for df_speaker Volkmar Vogel and real speaker ['Volkmar Uwe Vogel', 'Volkmar Vogel']
# No match found for df_speaker Reiner Haseloff and real speaker ['Christian Bartelt']
# No match found for df_speaker Georg Eisenreich and real speaker ['Christian Bartelt']
# Match found for df_speaker Bela Bach and real speaker ['Bela Bach']
# Match found for df_speaker Eva Högl and real speaker ['Eva Högl']
# Match found for df_speaker Matthias Nölke and real speaker ['Matthias Nölke']
# Match found for df_speaker Charlotte Schneidewind-Hartnagel and real speaker ['Charlotte Schneidewind-Hartnagel']
# Match found for df_speaker Karl-Josef Laumann and real speaker ['Karl-Josef Laumann']
# No match found for df_speaker Till Backhaus and real speaker ['Christian Bartelt']
# No match found for df_speaker Manuela Schwesig and real speaker ['Christian Bartelt']
# No match found for df_speaker Katja Meier and real speaker ['Christian Bartelt']
# Match found for df_speaker Elisabeth Winkelmeier-Becker and real speaker ['Elisabeth Winkelmeier-Becker']
# Match found for df_speaker Saskia Ludwig and real speaker ['Saskia Ludwig']
# No match found for df_speaker Georg Maier and real speaker ['Christian Bartelt']
# Match found for df_speaker Dagmar Ziegler and real speaker ['Dagmar Ziegler']
# Match found for df_speaker Christian Natterer and real speaker ['Christian Natterer']
# Match found for df_speaker Andreas Pinkwart and real speaker ['Andreas Pinkwart']
# Match found for df_speaker Christopher Gohl and real speaker ['Christopher Gohl']
# Match found for df_speaker Maika Friemann-Jennert and real speaker ['Maika Friemann-Jennert']
# No match found for df_speaker Felix Klein and real speaker ['Christian Bartelt']
# Match found for df_speaker Kristina Nordt and real speaker ['Kristina Nordt']
# No match found for df_speaker Peter Tschentscher and real speaker ['Christian Bartelt']

# %%
print(f'''
      Matched Parliament Members: {len(name_matches)}
      Not Matched: {len(no_name_matches)}
      Members with wrong Gender Classification: {len(no_gender_matches)}
      ''')
# Out:
#       Matched Parliament Members: 4338
#       Not Matched: 486
#       Members with wrong Gender Classification: 13

# %%
# print not-matched member names
for speaker in no_name_matches:
    name = df.loc[df['speaker_id'] == speaker, 'speaker_name'].iloc[0]
    print (f"{speaker}: {name}")

# %%
# print members with falsely classified gender
for speaker in no_gender_matches:
    print (df.loc[df['speaker_id'] == speaker, 'speaker_name'].iloc[0])
# Out:
# Gökay Akbulut
# Gerrit Huy
# Esra Limbacher
# Merle Spellerberg
# Misbah Khan
# Erni Finselberger
# Honor Funk
# Cornelie Sonntag-Wolgast
# Christina Schenk
# Kersten Steinke
# Hilde Mattheis
# Ulli Nissen
# Elvan Korkmaz

# %%
# replace false genders in dataframe
for speaker in no_gender_matches:
    rows = df[df['speaker_id'] == speaker]

    gender = df.loc[df['speaker_id'] == speaker, 'speaker_gender'].iloc[0]
    new_gender = 'male' if gender == 'female' else 'female'

    for index, row in rows.iterrows():
        df.loc[index, 'speaker_gender'] = new_gender

# %%
# check if successful
for speaker in no_gender_matches:
    print (df.loc[df['speaker_id'] == speaker, 'speaker_gender'].iloc[0])
# Out:
# female
# female
# male
# female
# female
# female
# male
# female
# male
# female
# female
# female
# female

# %%
# new gender counts
df.groupby('speaker_gender')['speaker_id'].nunique()
# Out:
# speaker_gender
# female    1064
# male      3649
# Name: speaker_id, dtype: int64

# %%
# save corrected dataframe
df.to_pickle('C:/Users/Ana/OneDrive - Hochschule Düsseldorf/MA/data_merged_revised.pkl')
